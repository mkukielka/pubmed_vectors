# %%
from pprint import pprint
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
import numpy as np
import random
import smart_open
from collections import defaultdict
from tqdm import tqdm
from joblib import Parallel, delayed
import networkx as nx

# %% [markdown]
# Glove evaluation refactored

# %%
def generate_base(model_path, vocab_path):
    with open(vocab_path, 'r+') as f:
        words = [x.rstrip().split(' ')[0] for x in f.readlines()]
    with open(model_path, 'r') as f:
        vectors = {}
        for line in f:
            vals = line.rstrip().split(' ')
            vectors[vals[0]] = [float(x) for x in vals[1:]]

    vocab_size = len(words)
    vocab = {w: idx for idx, w in enumerate(words)}
    ivocab = {idx: w for idx, w in enumerate(words)}

    vector_dim = len(vectors[ivocab[0]])
    W = np.zeros((vocab_size, vector_dim))
    for word, v in vectors.items():
        if word == '<unk>':
            continue
        W[vocab[word], :] = v

    # normalize each word vector to unit variance
    W_norm = np.zeros(W.shape)
    d = (np.sum(W ** 2, 1) ** (0.5))
    W_norm = (W.T / d).T
    return (W_norm, vocab, ivocab)


def distance(base, input_term, topn):
    W, vocab, ivocab = base
    for idx, term in enumerate(input_term.split(' ')):
        if term in vocab:
            if idx == 0:
                vec_result = np.copy(W[vocab[term], :])
            else:
                vec_result += W[vocab[term], :]
        else:
            return # Word: Out of dictionary!

    vec_norm = np.zeros(vec_result.shape)
    d = (np.sum(vec_result ** 2,) ** (0.5))
    vec_norm = (vec_result.T / d).T

    dist = np.dot(W, vec_norm.T)

    for term in input_term.split(' '):
        index = vocab[term]
        dist[index] = -np.Inf

    a = np.argsort(-dist)[:topn]
    return [[ivocab[x], dist[x]] for x in a]

# %% [markdown]
# Get most similar words for code

# %%
def get_icd10_codes():
    icd10 = defaultdict()
    with open('../results/icd10cm_codes_2018.txt', 'r+') as f:
        for line in f.readlines():
            line = line.split()
            icd10[line[0].lower()] = ' '.join(line[1:]).lower()
        return icd10
    
    
def validate_relations(similarity_results, icd10):
    """Filter found words by cheking, whether they're valid icd10 codes."""
    found_relations = defaultdict(list)
    for reference, codes in tqdm(similarity_results.items()):
        for code, score in codes:
            if code.lower() in icd10.keys():
                found_relations[reference].append(code.lower())
    return found_relations


def describe_relations(found_relations, icd10):
    """Annotate every relation with titles of contained codes"""
    described_relations = defaultdict(list)
    for reference, relations in found_relations.items():
        for relation in relations:
            described_relations[(reference, relation)].append(
                (icd10[reference], icd10[relation]))
    return described_relations


def perform_analysis(model_path, vocab_path, topn=50):
    """Find relations between icd10 codes."""
    icd10 = get_icd10_codes()
    print('Loading vocabulary and vectors...')
    base = generate_base(model_path, vocab_path)
    print('Retrieving similar words...')
    similarity = Parallel(n_jobs=-1, backend='threading', verbose=10)(
        delayed(distance)(base, code, topn) for code in icd10.keys())
    similarity_results = defaultdict(list)
    for code, relations in zip(icd10.keys(), similarity):
        if relations:
            similarity_results[code] = relations
    print('Filtering similarities...')
    validated_relations = validate_relations(similarity_results, icd10=icd10)
    print('Describing relations...')
    return describe_relations(validated_relations, icd10=icd10)

# %%
results = perform_analysis('../results/glove_data/symmetric_vectors/glove_vectors150.txt', '../results/filtered_vocab_10.txt', topn=1000)
# Out:
# Loading vocabulary and vectors...
# Retrieving similar words...
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 917 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 1050 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 1097 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 1193 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 1293 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 1344 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 1397 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 1505 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 1617 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 1674 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 1733 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done 1853 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 1914 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done 1977 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=-1)]: Done 2040 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 2105 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 2170 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 2237 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done 2304 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done 2373 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done 2513 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done 2584 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=-1)]: Done 2657 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 2730 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 2805 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done 2880 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 2957 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 3034 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 3113 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 3273 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 3354 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 3437 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done 3520 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done 3605 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 3690 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 3777 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 3864 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 3953 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 4133 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 4224 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done 4317 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=-1)]: Done 4410 tasks      | elapsed:   15.6s
# [Parallel(n_jobs=-1)]: Done 4505 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=-1)]: Done 4600 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done 4697 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done 4794 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=-1)]: Done 4893 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done 4992 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done 5093 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 5194 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 5297 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 5400 tasks      | elapsed:   18.2s
# [Parallel(n_jobs=-1)]: Done 5505 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=-1)]: Done 5610 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=-1)]: Done 5717 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done 5824 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=-1)]: Done 5933 tasks      | elapsed:   19.4s
# [Parallel(n_jobs=-1)]: Done 6042 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-1)]: Done 6153 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done 6264 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=-1)]: Done 6377 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done 6490 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done 6605 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=-1)]: Done 6720 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done 6837 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=-1)]: Done 6954 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=-1)]: Done 7073 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done 7192 tasks      | elapsed:   22.2s
# [Parallel(n_jobs=-1)]: Done 7313 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done 7434 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done 7557 tasks      | elapsed:   23.3s
# [Parallel(n_jobs=-1)]: Done 7680 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done 7805 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done 7930 tasks      | elapsed:   24.3s
# [Parallel(n_jobs=-1)]: Done 8057 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=-1)]: Done 8184 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-1)]: Done 8313 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-1)]: Done 8442 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=-1)]: Done 8573 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done 8704 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done 8837 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=-1)]: Done 8970 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=-1)]: Done 9105 tasks      | elapsed:   28.2s
# [Parallel(n_jobs=-1)]: Done 9240 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=-1)]: Done 9377 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=-1)]: Done 9514 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=-1)]: Done 9653 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 9792 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=-1)]: Done 9933 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 10074 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=-1)]: Done 10217 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done 10360 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 10505 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 10650 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=-1)]: Done 10797 tasks      | elapsed:   32.3s
# [Parallel(n_jobs=-1)]: Done 10944 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done 11093 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done 11242 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done 11393 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done 11544 tasks      | elapsed:   35.1s
# [Parallel(n_jobs=-1)]: Done 11697 tasks      | elapsed:   35.9s
# [Parallel(n_jobs=-1)]: Done 11850 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=-1)]: Done 12005 tasks      | elapsed:   36.7s
# [Parallel(n_jobs=-1)]: Done 12160 tasks      | elapsed:   37.1s
# [Parallel(n_jobs=-1)]: Done 12317 tasks      | elapsed:   37.2s
# [Parallel(n_jobs=-1)]: Done 12474 tasks      | elapsed:   37.9s
# [Parallel(n_jobs=-1)]: Done 12633 tasks      | elapsed:   38.4s
# [Parallel(n_jobs=-1)]: Done 12792 tasks      | elapsed:   38.4s
# [Parallel(n_jobs=-1)]: Done 12953 tasks      | elapsed:   39.2s
# [Parallel(n_jobs=-1)]: Done 13114 tasks      | elapsed:   39.7s
# [Parallel(n_jobs=-1)]: Done 13277 tasks      | elapsed:   40.8s
# [Parallel(n_jobs=-1)]: Done 13440 tasks      | elapsed:   40.9s
# [Parallel(n_jobs=-1)]: Done 13605 tasks      | elapsed:   41.3s
# [Parallel(n_jobs=-1)]: Done 13770 tasks      | elapsed:   41.4s
# [Parallel(n_jobs=-1)]: Done 13937 tasks      | elapsed:   41.6s
# [Parallel(n_jobs=-1)]: Done 14104 tasks      | elapsed:   42.5s
# [Parallel(n_jobs=-1)]: Done 14273 tasks      | elapsed:   42.9s
# [Parallel(n_jobs=-1)]: Done 14442 tasks      | elapsed:   43.7s
# [Parallel(n_jobs=-1)]: Done 14613 tasks      | elapsed:   44.1s
# [Parallel(n_jobs=-1)]: Done 14784 tasks      | elapsed:   45.1s
# [Parallel(n_jobs=-1)]: Done 14957 tasks      | elapsed:   45.6s
# [Parallel(n_jobs=-1)]: Done 15130 tasks      | elapsed:   46.0s
# [Parallel(n_jobs=-1)]: Done 15305 tasks      | elapsed:   46.7s
# [Parallel(n_jobs=-1)]: Done 15480 tasks      | elapsed:   47.2s
# [Parallel(n_jobs=-1)]: Done 15657 tasks      | elapsed:   47.6s
# [Parallel(n_jobs=-1)]: Done 15834 tasks      | elapsed:   48.0s
# [Parallel(n_jobs=-1)]: Done 16013 tasks      | elapsed:   48.4s
# [Parallel(n_jobs=-1)]: Done 16192 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=-1)]: Done 16373 tasks      | elapsed:   48.8s
# [Parallel(n_jobs=-1)]: Done 16554 tasks      | elapsed:   49.2s
# [Parallel(n_jobs=-1)]: Done 16737 tasks      | elapsed:   50.0s
# [Parallel(n_jobs=-1)]: Done 16920 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=-1)]: Done 17105 tasks      | elapsed:   50.7s
# [Parallel(n_jobs=-1)]: Done 17290 tasks      | elapsed:   51.1s
# [Parallel(n_jobs=-1)]: Done 17477 tasks      | elapsed:   51.6s
# [Parallel(n_jobs=-1)]: Done 17664 tasks      | elapsed:   52.4s
# [Parallel(n_jobs=-1)]: Done 17853 tasks      | elapsed:   52.4s
# [Parallel(n_jobs=-1)]: Done 18042 tasks      | elapsed:   52.8s
# [Parallel(n_jobs=-1)]: Done 18233 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=-1)]: Done 18424 tasks      | elapsed:   53.9s
# [Parallel(n_jobs=-1)]: Done 18617 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=-1)]: Done 18810 tasks      | elapsed:   54.9s
# [Parallel(n_jobs=-1)]: Done 19005 tasks      | elapsed:   55.3s
# [Parallel(n_jobs=-1)]: Done 19200 tasks      | elapsed:   55.8s
# [Parallel(n_jobs=-1)]: Done 19397 tasks      | elapsed:   56.2s
# [Parallel(n_jobs=-1)]: Done 19594 tasks      | elapsed:   57.0s
# [Parallel(n_jobs=-1)]: Done 19793 tasks      | elapsed:   57.7s
# [Parallel(n_jobs=-1)]: Done 19992 tasks      | elapsed:   58.5s
# [Parallel(n_jobs=-1)]: Done 20193 tasks      | elapsed:   58.6s
# [Parallel(n_jobs=-1)]: Done 20394 tasks      | elapsed:   59.3s
# [Parallel(n_jobs=-1)]: Done 20597 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 20800 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 21005 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 21210 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 21417 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 21624 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 21833 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 22042 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 22253 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 22464 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 22677 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 22890 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 23105 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 23320 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 23537 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 23754 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 23973 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 24192 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 24413 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 24634 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 24857 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 25080 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 25305 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 25530 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 25757 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 25984 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 26213 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 26442 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 26673 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 26904 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 27137 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 27370 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 27605 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 27840 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 28077 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 28314 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 28553 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 28792 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 29033 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 29274 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 29517 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 29760 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 30005 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 30250 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 30497 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 30744 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 30993 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 31242 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 31493 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 31744 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 31997 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 32250 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 32505 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 32760 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 33017 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 33274 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 33533 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 33792 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 34053 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 34314 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 34577 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 34840 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 35105 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 35370 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 35637 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 35904 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 36173 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 36442 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 36713 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 36984 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 37257 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 37530 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 37805 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 38080 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 38357 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 38634 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 38913 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 39192 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 39473 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 39754 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 40037 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 40320 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 40605 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 40890 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 41177 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 41464 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 41753 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 42042 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 42333 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 42624 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 42917 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 43210 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 43505 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 43800 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 44097 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 44394 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 44693 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 44992 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 45293 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 45594 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 45897 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 46200 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 46505 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 46810 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 47117 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 47424 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 47733 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 48042 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 48353 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 48664 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 48977 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 49290 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 49605 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 49920 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 50237 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 50554 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 50873 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 51192 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 51513 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 51834 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 52157 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 52480 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 52805 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 53130 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 53457 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 53784 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 54113 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 54442 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 54773 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 55104 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 55437 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 55770 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 56105 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 56440 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 56777 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 57114 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 57453 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 57792 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 58133 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 58474 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 58817 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 59160 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 59505 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 59850 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 60197 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 60544 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 60893 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 61242 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 61593 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 61944 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 62297 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 62650 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 63005 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 63360 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 63717 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 64074 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 64433 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 64792 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 65153 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 65514 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 65877 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 66240 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 66605 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 66970 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 67337 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 67704 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 68073 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 68442 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 68813 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 69184 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 69557 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 69930 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 70305 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 70680 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 71057 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 71434 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 71704 out of 71704 | elapsed:  3.6min finished
#   6%|▌         | 105/1766 [00:00<00:01, 1042.46it/s]
# Filtering similarities...
# 100%|██████████| 1766/1766 [00:01<00:00, 1010.18it/s]
# Describing relations...

# %% [markdown]
# Saving relations

# %%
results
# Out:
# defaultdict(list,
#             {('p232',
#               'p503'): [('congenital pneumonia due to staphylococcus',
#                'newborn affected by hemorrhage into co-twin')],
#              ('h119',
#               'f310'): [('unspecified disorder of conjunctiva',
#                'bipolar disorder, current episode hypomanic')],
#              ('n486',
#               'g245'): [('induration penis plastica', 'blepharospasm')],
#              ('b89',
#               'b889'): [('unspecified parasitic disease',
#                'infestation, unspecified')],
#              ('m311',
#               'f553'): [('thrombotic microangiopathy',
#                'abuse of steroids or hormones')],
#              ('k433',
#               'k228'): [('parastomal hernia with obstruction, without gangrene',
#                'other specified diseases of esophagus')],
#              ('i32',
#               'p155'): [('pericarditis in diseases classified elsewhere',
#                'birth injury to external genitalia')],
#              ('c410',
#               'p550'): [('malignant neoplasm of bones of skull and face',
#                'rh isoimmunization of newborn')],
#              ('b873',
#               'r404'): [('nasopharyngeal myiasis',
#                'transient alteration of awareness')],
#              ('d139',
#               'c512'): [('benign neoplasm of ill-defined sites within the digestive system',
#                'malignant neoplasm of clitoris')],
#              ('c73',
#               'n901'): [('malignant neoplasm of thyroid gland',
#                'moderate vulvar dysplasia')],
#              ('i200',
#               'p910'): [('unstable angina', 'neonatal cerebral ischemia')],
#              ('r162',
#               'a222'): [('hepatomegaly with splenomegaly, not elsewhere classified',
#                'gastrointestinal anthrax')],
#              ('i43',
#               'b2701'): [('cardiomyopathy in diseases classified elsewhere',
#                'gammaherpesviral mononucleosis with polyneuropathy')],
#              ('d067',
#               'l00'): [('carcinoma in situ of other parts of cervix',
#                'staphylococcal scalded skin syndrome')],
#              ('h526',
#               'f333'): [('other disorders of refraction',
#                'major depressive disorder, recurrent, severe with psychotic symptoms')],
#              ('g729',
#               'e139'): [('myopathy, unspecified',
#                'other specified diabetes mellitus without complications')],
#              ('f312',
#               'c519'): [('bipolar disorder, current episode manic severe with psychotic features',
#                'malignant neoplasm of vulva, unspecified')],
#              ('c112',
#               'b150'): [('malignant neoplasm of lateral wall of nasopharynx',
#                'hepatitis a with hepatic coma')],
#              ('d034',
#               'q253'): [('melanoma in situ of scalp and neck',
#                'supravalvular aortic stenosis')],
#              ('r404',
#               'j42'): [('transient alteration of awareness',
#                'unspecified chronic bronchitis')],
#              ('n499',
#               'd020'): [('inflammatory disorder of unspecified male genital organ',
#                'carcinoma in situ of larynx')],
#              ('k251',
#               'f651'): [('acute gastric ulcer with perforation',
#                'transvestic fetishism')],
#              ('q212',
#               'd125'): [('atrioventricular septal defect',
#                'benign neoplasm of sigmoid colon')],
#              ('d352',
#               'q165'): [('benign neoplasm of pituitary gland',
#                'congenital malformation of inner ear')],
#              ('l293',
#               'k116'): [('anogenital pruritus, unspecified',
#                'mucocele of salivary gland')],
#              ('n736',
#               'd020'): [('female pelvic peritoneal adhesions (postinfective)',
#                'carcinoma in situ of larynx')],
#              ('p610',
#               'q242'): [('transient neonatal thrombocytopenia',
#                'cor triatriatum')],
#              ('r002',
#               'c253'): [('palpitations',
#                'malignant neoplasm of pancreatic duct')],
#              ('r401', 'b471'): [('stupor', 'actinomycetoma')],
#              ('p581',
#               'c601'): [('neonatal jaundice due to bleeding',
#                'malignant neoplasm of glans penis')],
#              ('q230',
#               'n750'): [('congenital stenosis of aortic valve',
#                "cyst of bartholin's gland")],
#              ('d374',
#               'q105'): [('neoplasm of uncertain behavior of colon',
#                'congenital stenosis and stricture of lacrimal duct')],
#              ('n801',
#               'k433'): [('endometriosis of ovary',
#                'parastomal hernia with obstruction, without gangrene')],
#              ('n411',
#               'p113'): [('chronic prostatitis',
#                'birth injury to facial nerve')],
#              ('p505',
#               'y743'): [("newborn affected by intrauterine (fetal) blood loss from cut end of co-twin's cord",
#                'surgical instruments, materials and general hospital and personal-use devices (including sutures) associated with adverse incidents')],
#              ('y730',
#               'd492'): [('diagnostic and monitoring gastroenterology and urology devices associated with adverse incidents',
#                'neoplasm of unspecified behavior of bone, soft tissue, and skin')],
#              ('n393',
#               'n871'): [('stress incontinence (female) (male)',
#                'moderate cervical dysplasia')],
#              ('o80',
#               'd354'): [('encounter for full-term uncomplicated delivery',
#                'benign neoplasm of pineal gland')],
#              ('m109',
#               'p016'): [('gout, unspecified',
#                'newborn affected by maternal death')],
#              ('k274',
#               'b500'): [('chronic or unspecified peptic ulcer, site unspecified, with hemorrhage',
#                'plasmodium falciparum malaria with cerebral complications')],
#              ('n988',
#               'h36'): [('other complications associated with artificial fertilization',
#                'retinal disorders in diseases classified elsewhere')],
#              ('a159',
#               'n931'): [('respiratory tuberculosis unspecified',
#                'pre-pubertal vaginal bleeding')],
#              ('n402',
#               'o901'): [('nodular prostate without lower urinary tract symptoms',
#                'disruption of perineal obstetric wound')],
#              ('n489',
#               'p810'): [('disorder of penis, unspecified',
#                'environmental hyperthermia of newborn')],
#              ('f320',
#               'n171'): [('major depressive disorder, single episode, mild',
#                'acute kidney failure with acute cortical necrosis')],
#              ('k225',
#               'g1221'): [('diverticulum of esophagus, acquired',
#                'amyotrophic lateral sclerosis')],
#              ('k219',
#               'e59'): [('gastro-esophageal reflux disease without esophagitis',
#                'dietary selenium deficiency')],
#              ('b75',
#               'n903'): [('trichinellosis', 'dysplasia of vulva, unspecified')],
#              ('g245',
#               'n184'): [('blepharospasm',
#                'chronic kidney disease, stage 4 (severe)')],
#              ('k282',
#               'd420'): [('acute gastrojejunal ulcer with both hemorrhage and perforation',
#                'neoplasm of uncertain behavior of cerebral meninges')],
#              ('l210', 'e221'): [('seborrhea capitis', 'hyperprolactinemia')],
#              ('c104',
#               'r222'): [('malignant neoplasm of branchial cleft',
#                'localized swelling, mass and lump, trunk')],
#              ('n915',
#               'n002'): [('oligomenorrhea, unspecified',
#                'acute nephritic syndrome with diffuse membranous glomerulonephritis')],
#              ('q243',
#               'j311'): [('pulmonary infundibular stenosis',
#                'chronic nasopharyngitis')],
#              ('c701',
#               'd181'): [('malignant neoplasm of spinal meninges',
#                'lymphangioma, any site')],
#              ('a187',
#               'k200'): [('tuberculosis of adrenal glands',
#                'eosinophilic esophagitis')],
#              ('d135',
#               'p139'): [('benign neoplasm of extrahepatic bile ducts',
#                'birth injury to skeleton, unspecified')],
#              ('e270',
#               'n841'): [('other adrenocortical overactivity',
#                'polyp of cervix uteri')],
#              ('p551',
#               'm153'): [('abo isoimmunization of newborn',
#                'secondary multiple arthritis')],
#              ('d241',
#               'l130'): [('benign neoplasm of right breast',
#                'dermatitis herpetiformis')],
#              ('e233',
#               'a411'): [('hypothalamic dysfunction, not elsewhere classified',
#                'sepsis due to other specified staphylococcus')],
#              ('b510',
#               'n470'): [('plasmodium vivax malaria with rupture of spleen',
#                'adherent prepuce, newborn')],
#              ('d447',
#               'k136'): [('neoplasm of uncertain behavior of aortic body and other paraganglia',
#                'irritative hyperplasia of oral mucosa')],
#              ('p113',
#               'd512'): [('birth injury to facial nerve',
#                'transcobalamin ii deficiency')],
#              ('p015',
#               'n51'): [('newborn affected by multiple pregnancy',
#                'disorders of male genital organs in diseases classified elsewhere')],
#              ('d179',
#               'k601'): [('benign lipomatous neoplasm, unspecified',
#                'chronic anal fissure')],
#              ('r483',
#               'm301'): [('visual agnosia',
#                'polyarteritis with lung involvement [churg-strauss]')],
#              ('p013',
#               'r031'): [('newborn affected by polyhydramnios',
#                'nonspecific low blood-pressure reading')],
#              ('y632',
#               'd259'): [('overdose of radiation given during therapy',
#                'leiomyoma of uterus, unspecified')],
#              ('i43',
#               'p365'): [('cardiomyopathy in diseases classified elsewhere',
#                'sepsis of newborn due to anaerobes')],
#              ('f59',
#               'f73'): [('unspecified behavioral syndromes associated with physiological disturbances and physical factors',
#                'profound intellectual disabilities')],
#              ('i249',
#               'r150'): [('acute ischemic heart disease, unspecified',
#                'incomplete defecation')],
#              ('h318',
#               'b460'): [('other specified disorders of choroid',
#                'pulmonary mucormycosis')],
#              ('a303',
#               'e60'): [('borderline leprosy', 'dietary zinc deficiency')],
#              ('p016',
#               'm109'): [('newborn affected by maternal death',
#                'gout, unspecified')],
#              ('r140',
#               'n476'): [('abdominal distension (gaseous)', 'balanoposthitis')],
#              ('b460',
#               'h318'): [('pulmonary mucormycosis',
#                'other specified disorders of choroid')],
#              ('e229',
#               'f600'): [('hyperfunction of pituitary gland, unspecified',
#                'paranoid personality disorder')],
#              ('b500',
#               'd398'): [('plasmodium falciparum malaria with cerebral complications',
#                'neoplasm of uncertain behavior of other specified female genital organs')],
#              ('d816',
#               'l120'): [('major histocompatibility complex class i deficiency',
#                'bullous pemphigoid')],
#              ('d443',
#               'g119'): [('neoplasm of uncertain behavior of pituitary gland',
#                'hereditary ataxia, unspecified')],
#              ('a65',
#               'q226'): [('nonvenereal syphilis',
#                'hypoplastic right heart syndrome')],
#              ('d298',
#               'n343'): [('benign neoplasm of other specified male genital organs',
#                'urethral syndrome, unspecified')],
#              ('d020',
#               'n736'): [('carcinoma in situ of larynx',
#                'female pelvic peritoneal adhesions (postinfective)')],
#              ('d595',
#               'c189'): [('paroxysmal nocturnal hemoglobinuria [marchiafava-micheli]',
#                'malignant neoplasm of colon, unspecified')],
#              ('q222',
#               'g132'): [('congenital pulmonary valve insufficiency',
#                'systemic atrophy primarily affecting the central nervous system in myxedema')],
#              ('p261',
#               'c104'): [('massive pulmonary hemorrhage originating in the perinatal period',
#                'malignant neoplasm of branchial cleft')],
#              ('h2000',
#               'l512'): [('unspecified acute and subacute iridocyclitis',
#                'toxic epidermal necrolysis [lyell]')],
#              ('a33',
#               'p190'): [('tetanus neonatorum',
#                'metabolic acidemia in newborn first noted before onset of labor')],
#              ('y700',
#               'c494'): [('diagnostic and monitoring anesthesiology devices associated with adverse incidents',
#                'malignant neoplasm of connective and soft tissue of abdomen')],
#              ('k200',
#               'm273'): [('eosinophilic esophagitis', 'alveolitis of jaws')],
#              ('r196',
#               'c111'): [('halitosis',
#                'malignant neoplasm of posterior wall of nasopharynx')],
#              ('n341', 'r252'): [('nonspecific urethritis', 'cramp and spasm')],
#              ('m152',
#               'd170'): [("bouchard's nodes (with arthropathy)",
#                'benign lipomatous neoplasm of skin and subcutaneous tissue of head, face and neck')],
#              ('o113',
#               'e738'): [('pre-existing hypertension with pre-eclampsia, third trimester',
#                'other lactose intolerance')],
#              ('n19',
#               'p007'): [('unspecified kidney failure',
#                'newborn affected by other medical procedures on mother, not elsewhere classified')],
#              ('n770',
#               'r112'): [('ulceration of vulva in diseases classified elsewhere',
#                'nausea with vomiting, unspecified')],
#              ('e160',
#               'p233'): [('drug-induced hypoglycemia without coma',
#                'congenital pneumonia due to streptococcus, group b')],
#              ('c601',
#               'c677'): [('malignant neoplasm of glans penis',
#                'malignant neoplasm of urachus')],
#              ('r188', 'r203'): [('other ascites', 'hyperesthesia')],
#              ('c186',
#               'a187'): [('malignant neoplasm of descending colon',
#                'tuberculosis of adrenal glands')],
#              ('c101',
#               'd235'): [('malignant neoplasm of anterior surface of epiglottis',
#                'other benign neoplasm of skin of trunk')],
#              ('y69',
#               'n441'): [('unspecified misadventure during surgical and medical care',
#                'cyst of tunica albuginea testis')],
#              ('r221',
#               'a182'): [('localized swelling, mass and lump, neck',
#                'tuberculous peripheral lymphadenopathy')],
#              ('a187',
#               'm273'): [('tuberculosis of adrenal glands',
#                'alveolitis of jaws')],
#              ('a420',
#               'b5801'): [('pulmonary actinomycosis',
#                'toxoplasma chorioretinitis')],
#              ('c480',
#               'p619'): [('malignant neoplasm of retroperitoneum',
#                'perinatal hematological disorder, unspecified')],
#              ('a411',
#               'a054'): [('sepsis due to other specified staphylococcus',
#                'foodborne bacillus cereus intoxication')],
#              ('e299',
#               'd102'): [('testicular dysfunction, unspecified',
#                'benign neoplasm of floor of mouth')],
#              ('f04',
#               'q180'): [('amnestic disorder due to known physiological condition',
#                'sinus, fistula and cyst of branchial cleft')],
#              ('n312',
#               'n539'): [('flaccid neuropathic bladder, not elsewhere classified',
#                'unspecified male sexual dysfunction')],
#              ('d308',
#               'r220'): [('benign neoplasm of other specified urinary organs',
#                'localized swelling, mass and lump, head')],
#              ('a362',
#               'e041'): [('laryngeal diphtheria',
#                'nontoxic single thyroid nodule')],
#              ('c220', 'r12'): [('liver cell carcinoma', 'heartburn')],
#              ('g20',
#               'r849'): [("parkinson's disease",
#                'unspecified abnormal finding in specimens from respiratory organs and thorax')],
#              ('c320',
#               'r54'): [('malignant neoplasm of glottis',
#                'age-related physical debility')],
#              ('e275',
#               'p134'): [('adrenomedullary hyperfunction',
#                'fracture of clavicle due to birth injury')],
#              ('p045',
#               'n119'): [('newborn affected by maternal use of nutritional chemical substances',
#                'chronic tubulo-interstitial nephritis, unspecified')],
#              ('f21',
#               'p153'): [('schizotypal disorder', 'birth injury to eye')],
#              ('p011',
#               'r031'): [('newborn affected by premature rupture of membranes',
#                'nonspecific low blood-pressure reading')],
#              ('p521',
#               'g544'): [('intraventricular (nontraumatic) hemorrhage, grade 2, of newborn',
#                'lumbosacral root disorders, not elsewhere classified')],
#              ('d431',
#               'p141'): [('neoplasm of uncertain behavior of brain, infratentorial',
#                "klumpke's paralysis due to birth injury")],
#              ('c003',
#               'k437'): [('malignant neoplasm of upper lip, inner aspect',
#                'other and unspecified ventral hernia with gangrene')],
#              ('r239', 'q02'): [('unspecified skin changes', 'microcephaly')],
#              ('p159',
#               'i152'): [('birth injury, unspecified',
#                'hypertension secondary to endocrine disorders')],
#              ('b356',
#               'p521'): [('tinea cruris',
#                'intraventricular (nontraumatic) hemorrhage, grade 2, of newborn')],
#              ('m153',
#               'k37'): [('secondary multiple arthritis',
#                'unspecified appendicitis')],
#              ('p0449',
#               'a239'): [('newborn affected by maternal use of other drugs of addiction',
#                'brucellosis, unspecified')],
#              ('h42',
#               'r12'): [('glaucoma in diseases classified elsewhere',
#                'heartburn')],
#              ('m184',
#               'y658'): [('other bilateral secondary osteoarthritis of first carpometacarpal joints',
#                'other specified misadventures during surgical and medical care')],
#              ('r130',
#               'p252'): [('aphagia',
#                'pneumomediastinum originating in the perinatal period')],
#              ('d242',
#               'd235'): [('benign neoplasm of left breast',
#                'other benign neoplasm of skin of trunk')],
#              ('b150',
#               'k312'): [('hepatitis a with hepatic coma',
#                'hourglass stricture and stenosis of stomach')],
#              ('d250',
#               'f553'): [('submucous leiomyoma of uterus',
#                'abuse of steroids or hormones')],
#              ('c165',
#               'r221'): [('malignant neoplasm of lesser curvature of stomach, unspecified',
#                'localized swelling, mass and lump, neck')],
#              ('n358',
#               'm170'): [('other urethral stricture',
#                'bilateral primary osteoarthritis of knee')],
#              ('n882',
#               'n837'): [('stricture and stenosis of cervix uteri',
#                'hematoma of broad ligament')],
#              ('d354',
#               'p152'): [('benign neoplasm of pineal gland',
#                'sternomastoid injury due to birth injury')],
#              ('c37',
#               'q111'): [('malignant neoplasm of thymus',
#                'other anophthalmos')],
#              ('l102',
#               'r37'): [('pemphigus foliaceous',
#                'sexual dysfunction, unspecified')],
#              ('f910',
#               'n816'): [('conduct disorder confined to family context',
#                'rectocele')],
#              ('c100',
#               'l14'): [('malignant neoplasm of vallecula',
#                'bullous disorders in diseases classified elsewhere')],
#              ('m179',
#               'm5114'): [('osteoarthritis of knee, unspecified',
#                'intervertebral disc disorders with radiculopathy, thoracic region')],
#              ('n6022',
#               'l104'): [('fibroadenosis of left breast',
#                'pemphigus erythematosus')],
#              ('p221',
#               'k048'): [('transient tachypnea of newborn', 'radicular cyst')],
#              ('c494',
#               'p261'): [('malignant neoplasm of connective and soft tissue of abdomen',
#                'massive pulmonary hemorrhage originating in the perinatal period')],
#              ('k317',
#               'd290'): [('polyp of stomach and duodenum',
#                'benign neoplasm of penis')],
#              ('g111',
#               'a301'): [('early-onset cerebellar ataxia',
#                'tuberculoid leprosy')],
#              ('f553',
#               'm311'): [('abuse of steroids or hormones',
#                'thrombotic microangiopathy')],
#              ('i256',
#               'p960'): [('silent myocardial ischemia',
#                'congenital renal failure')],
#              ('d267',
#               'd77'): [('other benign neoplasm of other parts of uterus',
#                'other disorders of blood and blood-forming organs in diseases classified elsewhere')],
#              ('k265',
#               'c463'): [('chronic or unspecified duodenal ulcer with perforation',
#                "kaposi's sarcoma of lymph nodes")],
#              ('f89',
#               'n643'): [('unspecified disorder of psychological development',
#                'galactorrhea not associated with childbirth')],
#              ('d125',
#               'q212'): [('benign neoplasm of sigmoid colon',
#                'atrioventricular septal defect')],
#              ('a213',
#               'm167'): [('gastrointestinal tularemia',
#                'other unilateral secondary osteoarthritis of hip')],
#              ('k314', 'r253'): [('gastric diverticulum', 'fasciculation')],
#              ('q203',
#               'j182'): [('discordant ventriculoarterial connection',
#                'hypostatic pneumonia, unspecified organism')],
#              ('r400', 'k315'): [('somnolence', 'obstruction of duodenum')],
#              ('d398',
#               'k274'): [('neoplasm of uncertain behavior of other specified female genital organs',
#                'chronic or unspecified peptic ulcer, site unspecified, with hemorrhage')],
#              ('d168',
#               'b89'): [('benign neoplasm of pelvic bones, sacrum and coccyx',
#                'unspecified parasitic disease')],
#              ('d141',
#               'a55'): [('benign neoplasm of larynx',
#                'chlamydial lymphogranuloma (venereum)')],
#              ('d512',
#               'a199'): [('transcobalamin ii deficiency',
#                'miliary tuberculosis, unspecified')],
#              ('a360',
#               'e301'): [('pharyngeal diphtheria', 'precocious puberty')],
#              ('i280',
#               't3262'): [('arteriovenous fistula of pulmonary vessels',
#                'corrosions involving 60-69% of body surface with 20-29% third degree corrosion')],
#              ('b003',
#               'd890'): [('herpesviral meningitis',
#                'polyclonal hypergammaglobulinemia')],
#              ('i280',
#               'y731'): [('arteriovenous fistula of pulmonary vessels',
#                'therapeutic (nonsurgical) and rehabilitative gastroenterology and urology devices associated with adverse incidents')],
#              ('e54',
#               'c261'): [('ascorbic acid deficiency',
#                'malignant neoplasm of spleen')],
#              ('n630',
#               'n471'): [('unspecified lump in unspecified breast',
#                'phimosis')],
#              ('m7741',
#               'p271'): [('metatarsalgia, right foot',
#                'bronchopulmonary dysplasia originating in the perinatal period')],
#              ('p007',
#               'n19'): [('newborn affected by other medical procedures on mother, not elsewhere classified',
#                'unspecified kidney failure')],
#              ('a412',
#               'l300'): [('sepsis due to unspecified staphylococcus',
#                'nummular dermatitis')],
#              ('m179',
#               'k87'): [('osteoarthritis of knee, unspecified',
#                'disorders of gallbladder, biliary tract and pancreas in diseases classified elsewhere')],
#              ('f411', 'r351'): [('generalized anxiety disorder', 'nocturia')],
#              ('l530', 'm273'): [('toxic erythema', 'alveolitis of jaws')],
#              ('m311',
#               'd309'): [('thrombotic microangiopathy',
#                'benign neoplasm of urinary organ, unspecified')],
#              ('c714',
#               'd117'): [('malignant neoplasm of occipital lobe',
#                'benign neoplasm of other major salivary glands')],
#              ('p191',
#               'e163'): [('metabolic acidemia in newborn first noted during labor',
#                'increased secretion of glucagon')],
#              ('a187',
#               'l530'): [('tuberculosis of adrenal glands', 'toxic erythema')],
#              ('d447',
#               'f951'): [('neoplasm of uncertain behavior of aortic body and other paraganglia',
#                'chronic motor or vocal tic disorder')],
#              ('l309',
#               'b89'): [('dermatitis, unspecified',
#                'unspecified parasitic disease')],
#              ('i425',
#               'd352'): [('other restrictive cardiomyopathy',
#                'benign neoplasm of pituitary gland')],
#              ('p152',
#               'd354'): [('sternomastoid injury due to birth injury',
#                'benign neoplasm of pineal gland')],
#              ('f200',
#               'z944'): [('paranoid schizophrenia', 'liver transplant status')],
#              ('a208',
#               'd251'): [('other forms of plague',
#                'intramural leiomyoma of uterus')],
#              ('d299',
#               'g120'): [('benign neoplasm of male genital organ, unspecified',
#                'infantile spinal muscular atrophy, type i [werdnig-hoffman]')],
#              ('r290',
#               'f79'): [('tetany', 'unspecified intellectual disabilities')],
#              ('i110',
#               'r300'): [('hypertensive heart disease with heart failure',
#                'dysuria')],
#              ('j112',
#               'k225'): [('influenza due to unidentified influenza virus with gastrointestinal manifestations',
#                'diverticulum of esophagus, acquired')],
#              ('r231',
#               'p362'): [('pallor',
#                'sepsis of newborn due to staphylococcus aureus')],
#              ('k812',
#               'd279'): [('acute cholecystitis with chronic cholecystitis',
#                'benign neoplasm of unspecified ovary')],
#              ('q209',
#               'c542'): [('congenital malformation of cardiac chambers and connections, unspecified',
#                'malignant neoplasm of myometrium')],
#              ('e299',
#               'i289'): [('testicular dysfunction, unspecified',
#                'disease of pulmonary vessels, unspecified')],
#              ('p192',
#               'p119'): [('metabolic acidemia noted at birth',
#                'birth injury to central nervous system, unspecified')],
#              ('r239',
#               'n750'): [('unspecified skin changes',
#                "cyst of bartholin's gland")],
#              ('k23',
#               'o119'): [('disorders of esophagus in diseases classified elsewhere',
#                'pre-existing hypertension with pre-eclampsia, unspecified trimester')],
#              ('c482',
#               'k228'): [('malignant neoplasm of peritoneum, unspecified',
#                'other specified diseases of esophagus')],
#              ('r17',
#               'n719'): [('unspecified jaundice',
#                'inflammatory disease of uterus, unspecified')],
#              ('e59',
#               'l210'): [('dietary selenium deficiency', 'seborrhea capitis')],
#              ('d002',
#               'j182'): [('carcinoma in situ of stomach',
#                'hypostatic pneumonia, unspecified organism')],
#              ('r600',
#               'r21'): [('localized edema',
#                'rash and other nonspecific skin eruption')],
#              ('f340',
#               'e211'): [('cyclothymic disorder',
#                'secondary hyperparathyroidism, not elsewhere classified')],
#              ('r192',
#               'm179'): [('visible peristalsis',
#                'osteoarthritis of knee, unspecified')],
#              ('r001',
#               'd090'): [('bradycardia, unspecified',
#                'carcinoma in situ of bladder')],
#              ('d431',
#               'd269'): [('neoplasm of uncertain behavior of brain, infratentorial',
#                'other benign neoplasm of uterus, unspecified')],
#              ('n477',
#               'd386'): [('other inflammatory diseases of prepuce',
#                'neoplasm of uncertain behavior of respiratory organ, unspecified')],
#              ('r239',
#               'm342'): [('unspecified skin changes',
#                'systemic sclerosis induced by drug and chemical')],
#              ('q263',
#               'd179'): [('partial anomalous pulmonary venous connection',
#                'benign lipomatous neoplasm, unspecified')],
#              ('r231', 'k113'): [('pallor', 'abscess of salivary gland')],
#              ('a420',
#               'l130'): [('pulmonary actinomycosis',
#                'dermatitis herpetiformis')],
#              ('q203',
#               'j121'): [('discordant ventriculoarterial connection',
#                'respiratory syncytial virus pneumonia')],
#              ('n251',
#               'k256'): [('nephrogenic diabetes insipidus',
#                'chronic or unspecified gastric ulcer with both hemorrhage and perforation')],
#              ('z114',
#               'p0508'): [('encounter for screening for human immunodeficiency virus [hiv]',
#                'newborn light for gestational age, 2000-2499 grams')],
#              ('m109',
#               'p017'): [('gout, unspecified',
#                'newborn affected by malpresentation before labor')],
#              ('n319',
#               'n320'): [('neuromuscular dysfunction of bladder, unspecified',
#                'bladder-neck obstruction')],
#              ('n840',
#               'f89'): [('polyp of corpus uteri',
#                'unspecified disorder of psychological development')],
#              ('p742',
#               'c701'): [('disturbances of sodium balance of newborn',
#                'malignant neoplasm of spinal meninges')],
#              ('d241',
#               'a420'): [('benign neoplasm of right breast',
#                'pulmonary actinomycosis')],
#              ('e42',
#               'k860'): [('marasmic kwashiorkor',
#                'alcohol-induced chronic pancreatitis')],
#              ('k610',
#               'c179'): [('anal abscess',
#                'malignant neoplasm of small intestine, unspecified')],
#              ('d281',
#               'd332'): [('benign neoplasm of vagina',
#                'benign neoplasm of brain, unspecified')],
#              ('m2100',
#               'a380'): [('valgus deformity, not elsewhere classified, unspecified site',
#                'scarlet fever with otitis media')],
#              ('r0609',
#               'r012'): [('other forms of dyspnea', 'other cardiac sounds')],
#              ('n135',
#               'p271'): [('crossing vessel and stricture of ureter without hydronephrosis',
#                'bronchopulmonary dysplasia originating in the perinatal period')],
#              ('l210',
#               'k219'): [('seborrhea capitis',
#                'gastro-esophageal reflux disease without esophagitis')],
#              ('y69',
#               'd235'): [('unspecified misadventure during surgical and medical care',
#                'other benign neoplasm of skin of trunk')],
#              ('i422',
#               'p140'): [('other hypertrophic cardiomyopathy',
#                "erb's paralysis due to birth injury")],
#              ('c260',
#               'a488'): [('malignant neoplasm of intestinal tract, part unspecified',
#                'other specified bacterial diseases')],
#              ('c714',
#               'p370'): [('malignant neoplasm of occipital lobe',
#                'congenital tuberculosis')],
#              ('l605',
#               'd360'): [('yellow nail syndrome',
#                'benign neoplasm of lymph nodes')],
#              ('d234',
#               'k67'): [('other benign neoplasm of skin of scalp and neck',
#                'disorders of peritoneum in infectious diseases classified elsewhere')],
#              ('p370',
#               'y731'): [('congenital tuberculosis',
#                'therapeutic (nonsurgical) and rehabilitative gastroenterology and urology devices associated with adverse incidents')],
#              ('n503',
#               'n522'): [('cyst of epididymis',
#                'drug-induced erectile dysfunction')],
#              ('f54',
#               'c609'): [('psychological and behavioral factors associated with disorders or diseases classified elsewhere',
#                'malignant neoplasm of penis, unspecified')],
#              ('z944',
#               'n610'): [('liver transplant status',
#                'mastitis without abscess')],
#              ('n528',
#               'b380'): [('other male erectile dysfunction',
#                'acute pulmonary coccidioidomycosis')],
#              ('p0229',
#               'n836'): [('newborn affected by other morphological and functional abnormalities of placenta',
#                'hematosalpinx')],
#              ('n251',
#               'k37'): [('nephrogenic diabetes insipidus',
#                'unspecified appendicitis')],
#              ('a91',
#               'd015'): [('dengue hemorrhagic fever',
#                'carcinoma in situ of liver, gallbladder and bile ducts')],
#              ('d181',
#               'p742'): [('lymphangioma, any site',
#                'disturbances of sodium balance of newborn')],
#              ('m169',
#               'k87'): [('osteoarthritis of hip, unspecified',
#                'disorders of gallbladder, biliary tract and pancreas in diseases classified elsewhere')],
#              ('d061',
#               'n477'): [('carcinoma in situ of exocervix',
#                'other inflammatory diseases of prepuce')],
#              ('n418',
#               'c260'): [('other inflammatory diseases of prostate',
#                'malignant neoplasm of intestinal tract, part unspecified')],
#              ('m342',
#               'd298'): [('systemic sclerosis induced by drug and chemical',
#                'benign neoplasm of other specified male genital organs')],
#              ('m342',
#               'q02'): [('systemic sclerosis induced by drug and chemical',
#                'microcephaly')],
#              ('a270',
#               'r209'): [('leptospirosis icterohemorrhagica',
#                'unspecified disturbances of skin sensation')],
#              ('d432',
#               'i249'): [('neoplasm of uncertain behavior of brain, unspecified',
#                'acute ischemic heart disease, unspecified')],
#              ('c384',
#               'p159'): [('malignant neoplasm of pleura',
#                'birth injury, unspecified')],
#              ('p239',
#               'p119'): [('congenital pneumonia, unspecified',
#                'birth injury to central nervous system, unspecified')],
#              ('m129',
#               'z66'): [('arthropathy, unspecified', 'do not resuscitate')],
#              ('m910',
#               'd090'): [('juvenile osteochondrosis of pelvis',
#                'carcinoma in situ of bladder')],
#              ('e244',
#               't304'): [("alcohol-induced pseudo-cushing's syndrome",
#                'corrosion of unspecified body region, unspecified degree')],
#              ('l86',
#               'd061'): [('keratoderma in diseases classified elsewhere',
#                'carcinoma in situ of exocervix')],
#              ('f82',
#               'f632'): [('specific developmental disorder of motor function',
#                'kleptomania')],
#              ('n441',
#               'd166'): [('cyst of tunica albuginea testis',
#                'benign neoplasm of vertebral column')],
#              ('k252',
#               'o151'): [('acute gastric ulcer with both hemorrhage and perforation',
#                'eclampsia complicating labor')],
#              ('e161', 'q122'): [('other hypoglycemia', 'coloboma of lens')],
#              ('o151',
#               'k252'): [('eclampsia complicating labor',
#                'acute gastric ulcer with both hemorrhage and perforation')],
#              ('a212',
#               'e329'): [('pulmonary tularemia',
#                'disease of thymus, unspecified')],
#              ('m301',
#               'r483'): [('polyarteritis with lung involvement [churg-strauss]',
#                'visual agnosia')],
#              ('e161',
#               'p251'): [('other hypoglycemia',
#                'pneumothorax originating in the perinatal period')],
#              ('r142',
#               'd259'): [('eructation', 'leiomyoma of uterus, unspecified')],
#              ('m169',
#               'm5114'): [('osteoarthritis of hip, unspecified',
#                'intervertebral disc disorders with radiculopathy, thoracic region')],
#              ('y701',
#               'h32'): [('therapeutic (nonsurgical) and rehabilitative anesthesiology devices associated with adverse incidents',
#                'chorioretinal disorders in diseases classified elsewhere')],
#              ('i43',
#               'l110'): [('cardiomyopathy in diseases classified elsewhere',
#                'acquired keratosis follicularis')],
#              ('p370',
#               'c714'): [('congenital tuberculosis',
#                'malignant neoplasm of occipital lobe')],
#              ('o630',
#               'k280'): [('prolonged first stage (of labor)',
#                'acute gastrojejunal ulcer with hemorrhage')],
#              ('d134',
#               'n841'): [('benign neoplasm of liver', 'polyp of cervix uteri')],
#              ('r270',
#               'm270'): [('ataxia, unspecified',
#                'developmental disorders of jaws')],
#              ('c166',
#               'r159'): [('malignant neoplasm of greater curvature of stomach, unspecified',
#                'full incontinence of feces')],
#              ('p138',
#               'k252'): [('birth injuries to other parts of skeleton',
#                'acute gastric ulcer with both hemorrhage and perforation')],
#              ('q143',
#               'k77'): [('congenital malformation of choroid',
#                'liver disorders in diseases classified elsewhere')],
#              ('k149',
#               'k315'): [('disease of tongue, unspecified',
#                'obstruction of duodenum')],
#              ('n477',
#               'h318'): [('other inflammatory diseases of prepuce',
#                'other specified disorders of choroid')],
#              ('g450',
#               'k257'): [('vertebro-basilar artery syndrome',
#                'chronic gastric ulcer without hemorrhage or perforation')],
#              ('r065', 'n150'): [('mouth breathing', 'balkan nephropathy')],
#              ('f314',
#               'd630'): [('bipolar disorder, current episode depressed, severe, without psychotic features',
#                'anemia in neoplastic disease')],
#              ('a232',
#               'p503'): [('brucellosis due to brucella suis',
#                'newborn affected by hemorrhage into co-twin')],
#              ('o901',
#               'n402'): [('disruption of perineal obstetric wound',
#                'nodular prostate without lower urinary tract symptoms')],
#              ('n420',
#               'd471'): [('calculus of prostate',
#                'chronic myeloproliferative disease')],
#              ('y753',
#               'q300'): [('surgical instruments, materials and neurological devices (including sutures) associated with adverse incidents',
#                'choanal atresia')],
#              ('k271',
#               'l52'): [('acute peptic ulcer, site unspecified, with perforation',
#                'erythema nodosum')],
#              ('d104',
#               'k353'): [('benign neoplasm of tonsil',
#                'acute appendicitis with localized peritonitis')],
#              ('d279',
#               'c187'): [('benign neoplasm of unspecified ovary',
#                'malignant neoplasm of sigmoid colon')],
#              ('a320', 'r0781'): [('cutaneous listeriosis', 'pleurodynia')],
#              ('a184',
#               'r152'): [('tuberculosis of skin and subcutaneous tissue',
#                'fecal urgency')],
#              ('p712', 'r130'): [('neonatal hypomagnesemia', 'aphagia')],
#              ('c792',
#               'o85'): [('secondary malignant neoplasm of skin',
#                'puerperal sepsis')],
#              ('p261',
#               'c52'): [('massive pulmonary hemorrhage originating in the perinatal period',
#                'malignant neoplasm of vagina')],
#              ('p370',
#               'm174'): [('congenital tuberculosis',
#                'other bilateral secondary osteoarthritis of knee')],
#              ('n838',
#               'f04'): [('other noninflammatory disorders of ovary, fallopian tube and broad ligament',
#                'amnestic disorder due to known physiological condition')],
#              ('n945',
#               'r34'): [('secondary dysmenorrhea', 'anuria and oliguria')],
#              ('r270',
#               'q243'): [('ataxia, unspecified',
#                'pulmonary infundibular stenosis')],
#              ('n136',
#               'p030'): [('pyonephrosis',
#                'newborn affected by breech delivery and extraction')],
#              ('n841',
#               'r37'): [('polyp of cervix uteri',
#                'sexual dysfunction, unspecified')],
#              ('k250',
#               'd090'): [('acute gastric ulcer with hemorrhage',
#                'carcinoma in situ of bladder')],
#              ('e1100',
#               'r820'): [('type 2 diabetes mellitus with hyperosmolarity without nonketotic hyperglycemic-hyperosmolar coma (nkhhc)',
#                'chyluria')],
#              ('p132',
#               'd270'): [('birth injury to femur',
#                'benign neoplasm of right ovary')],
#              ('r0481',
#               'f304'): [('acute idiopathic pulmonary hemorrhage in infants',
#                'manic episode in full remission')],
#              ('f330',
#               'd492'): [('major depressive disorder, recurrent, mild',
#                'neoplasm of unspecified behavior of bone, soft tissue, and skin')],
#              ('p141',
#               'd431'): [("klumpke's paralysis due to birth injury",
#                'neoplasm of uncertain behavior of brain, infratentorial')],
#              ('k251',
#               'p141'): [('acute gastric ulcer with perforation',
#                "klumpke's paralysis due to birth injury")],
#              ('e299',
#               'l240'): [('testicular dysfunction, unspecified',
#                'irritant contact dermatitis due to detergents')],
#              ('p148',
#               'y751'): [('birth injuries to other parts of peripheral nervous system',
#                'therapeutic (nonsurgical) and rehabilitative neurological devices associated with adverse incidents')],
#              ('p551',
#               'k256'): [('abo isoimmunization of newborn',
#                'chronic or unspecified gastric ulcer with both hemorrhage and perforation')],
#              ('m5114',
#               'm179'): [('intervertebral disc disorders with radiculopathy, thoracic region',
#                'osteoarthritis of knee, unspecified')],
#              ('k134',
#               'j60'): [('granuloma and granuloma-like lesions of oral mucosa',
#                "coalworker's pneumoconiosis")],
#              ('d282',
#               'f411'): [('benign neoplasm of uterine tubes and ligaments',
#                'generalized anxiety disorder')],
#              ('p252',
#               'p712'): [('pneumomediastinum originating in the perinatal period',
#                'neonatal hypomagnesemia')],
#              ('c482',
#               'n801'): [('malignant neoplasm of peritoneum, unspecified',
#                'endometriosis of ovary')],
#              ('k433',
#               'c482'): [('parastomal hernia with obstruction, without gangrene',
#                'malignant neoplasm of peritoneum, unspecified')],
#              ('p119',
#               'l104'): [('birth injury to central nervous system, unspecified',
#                'pemphigus erythematosus')],
#              ('p113',
#               'n433'): [('birth injury to facial nerve',
#                'hydrocele, unspecified')],
#              ('b80', 'a835'): [('enterobiasis', 'california encephalitis')],
#              ('i280',
#               'p370'): [('arteriovenous fistula of pulmonary vessels',
#                'congenital tuberculosis')],
#              ('e340', 'k627'): [('carcinoid syndrome', 'radiation proctitis')],
#              ('p110',
#               'c160'): [('cerebral edema due to birth injury',
#                'malignant neoplasm of cardia')],
#              ('i150',
#               'c474'): [('renovascular hypertension',
#                'malignant neoplasm of peripheral nerves of abdomen')],
#              ('n813',
#               'q311'): [('complete uterovaginal prolapse',
#                'congenital subglottic stenosis')],
#              ('d167',
#               'c186'): [('benign neoplasm of ribs, sternum and clavicle',
#                'malignant neoplasm of descending colon')],
#              ('d106',
#               'd130'): [('benign neoplasm of nasopharynx',
#                'benign neoplasm of esophagus')],
#              ('m450',
#               'p529'): [('ankylosing spondylitis of multiple sites in spine',
#                'intracranial (nontraumatic) hemorrhage of newborn, unspecified')],
#              ('m270',
#               'p0229'): [('developmental disorders of jaws',
#                'newborn affected by other morphological and functional abnormalities of placenta')],
#              ('d492',
#               'r51'): [('neoplasm of unspecified behavior of bone, soft tissue, and skin',
#                'headache')],
#              ('r230',
#               'l138'): [('cyanosis', 'other specified bullous disorders')],
#              ('l652',
#               'i96'): [('alopecia mucinosa',
#                'gangrene, not elsewhere classified')],
#              ('m910',
#               'k250'): [('juvenile osteochondrosis of pelvis',
#                'acute gastric ulcer with hemorrhage')],
#              ('e163',
#               'p191'): [('increased secretion of glucagon',
#                'metabolic acidemia in newborn first noted during labor')],
#              ('h36',
#               'i152'): [('retinal disorders in diseases classified elsewhere',
#                'hypertension secondary to endocrine disorders')],
#              ('e340',
#               'e261'): [('carcinoid syndrome',
#                'secondary hyperaldosteronism')],
#              ('g219',
#               'd164'): [('secondary parkinsonism, unspecified',
#                'benign neoplasm of bones of skull and face')],
#              ('d241',
#               'n803'): [('benign neoplasm of right breast',
#                'endometriosis of pelvic peritoneum')],
#              ('p294',
#               'a515'): [('transient myocardial ischemia in newborn',
#                'early syphilis, latent')],
#              ('q261',
#               'r58'): [('persistent left superior vena cava',
# ...
#              ('n750',
#               'm342'): [("cyst of bartholin's gland",
#                'systemic sclerosis induced by drug and chemical')],
#              ('e236',
#               'q242'): [('other disorders of pituitary gland',
#                'cor triatriatum')],
#              ('f314',
#               'a301'): [('bipolar disorder, current episode depressed, severe, without psychotic features',
#                'tuberculoid leprosy')],
#              ('b5801',
#               'k130'): [('toxoplasma chorioretinitis', 'diseases of lips')],
#              ('b20',
#               'p131'): [('human immunodeficiency virus [hiv] disease',
#                'other birth injuries to skull')],
#              ('k011',
#               'h3413'): [('impacted teeth',
#                'central retinal artery occlusion, bilateral')],
#              ('f800',
#               'n711'): [('phonological disorder',
#                'chronic inflammatory disease of uterus')],
#              ('p191',
#               'd354'): [('metabolic acidemia in newborn first noted during labor',
#                'benign neoplasm of pineal gland')],
#              ('p0518',
#               'd038'): [('newborn small for gestational age, 2000-2499 grams',
#                'melanoma in situ of other sites')],
#              ('t304',
#               'e244'): [('corrosion of unspecified body region, unspecified degree',
#                "alcohol-induced pseudo-cushing's syndrome")],
#              ('d408',
#               'd250'): [('neoplasm of uncertain behavior of other specified male genital organs',
#                'submucous leiomyoma of uterus')],
#              ('d127',
#               'b0802'): [('benign neoplasm of rectosigmoid junction',
#                'orf virus disease')],
#              ('d106',
#               'b663'): [('benign neoplasm of nasopharynx', 'fascioliasis')],
#              ('c189',
#               'e290'): [('malignant neoplasm of colon, unspecified',
#                'testicular hyperfunction')],
#              ('n801',
#               'c482'): [('endometriosis of ovary',
#                'malignant neoplasm of peritoneum, unspecified')],
#              ('p540',
#               'p251'): [('neonatal hematemesis',
#                'pneumothorax originating in the perinatal period')],
#              ('r162',
#               'k116'): [('hepatomegaly with splenomegaly, not elsewhere classified',
#                'mucocele of salivary gland')],
#              ('q323',
#               'p746'): [('congenital stenosis of bronchus',
#                'transitory hyperammonemia of newborn')],
#              ('f553',
#               'd235'): [('abuse of steroids or hormones',
#                'other benign neoplasm of skin of trunk')],
#              ('r498',
#               'r700'): [('other voice and resonance disorders',
#                'elevated erythrocyte sedimentation rate')],
#              ('q110',
#               'q148'): [('cystic eyeball',
#                'other congenital malformations of posterior segment of eye')],
#              ('i169',
#               'b479'): [('hypertensive crisis, unspecified',
#                'mycetoma, unspecified')],
#              ('c249',
#               'r296'): [('malignant neoplasm of biliary tract, unspecified',
#                'repeated falls')],
#              ('c482',
#               'l109'): [('malignant neoplasm of peritoneum, unspecified',
#                'pemphigus, unspecified')],
#              ('l102',
#               'n841'): [('pemphigus foliaceous', 'polyp of cervix uteri')],
#              ('d165',
#               'd224'): [('benign neoplasm of lower jaw bone',
#                'melanocytic nevi of scalp and neck')],
#              ('i152',
#               'p159'): [('hypertension secondary to endocrine disorders',
#                'birth injury, unspecified')],
#              ('e1040',
#               'n910'): [('type 1 diabetes mellitus with diabetic neuropathy, unspecified',
#                'primary amenorrhea')],
#              ('d039',
#               'd128'): [('melanoma in situ, unspecified',
#                'benign neoplasm of rectum')],
#              ('g238',
#               'i160'): [('other specified degenerative diseases of basal ganglia',
#                'hypertensive urgency')],
#              ('k604',
#               'f29'): [('rectal fistula',
#                'unspecified psychosis not due to a substance or known physiological condition')],
#              ('y740',
#               'p370'): [('diagnostic and monitoring general hospital and personal-use devices associated with adverse incidents',
#                'congenital tuberculosis')],
#              ('d119',
#               'f312'): [('benign neoplasm of major salivary gland, unspecified',
#                'bipolar disorder, current episode manic severe with psychotic features')],
#              ('c184',
#               'p103'): [('malignant neoplasm of transverse colon',
#                'subarachnoid hemorrhage due to birth injury')],
#              ('q132',
#               'a186'): [('other congenital malformations of iris',
#                'tuberculosis of (inner) (middle) ear')],
#              ('r37',
#               'e270'): [('sexual dysfunction, unspecified',
#                'other adrenocortical overactivity')],
#              ('p0441',
#               'f251'): [('newborn affected by maternal use of cocaine',
#                'schizoaffective disorder, depressive type')],
#              ('d110',
#               'z944'): [('benign neoplasm of parotid gland',
#                'liver transplant status')],
#              ('k145',
#               'y753'): [('plicated tongue',
#                'surgical instruments, materials and neurological devices (including sutures) associated with adverse incidents')],
#              ('y750',
#               'f413'): [('diagnostic and monitoring neurological devices associated with adverse incidents',
#                'other mixed anxiety disorders')],
#              ('r290', 'b471'): [('tetany', 'actinomycetoma')],
#              ('n159',
#               'd400'): [('renal tubulo-interstitial disease, unspecified',
#                'neoplasm of uncertain behavior of prostate')],
#              ('p159',
#               'c412'): [('birth injury, unspecified',
#                'malignant neoplasm of vertebral column')],
#              ('f413',
#               'y750'): [('other mixed anxiety disorders',
#                'diagnostic and monitoring neurological devices associated with adverse incidents')],
#              ('d164',
#               'b182'): [('benign neoplasm of bones of skull and face',
#                'chronic viral hepatitis c')],
#              ('q323',
#               'k582'): [('congenital stenosis of bronchus',
#                'mixed irritable bowel syndrome')],
#              ('m164',
#               'd281'): [('bilateral post-traumatic osteoarthritis of hip',
#                'benign neoplasm of vagina')],
#              ('y95', 'l80'): [('nosocomial condition', 'vitiligo')],
#              ('r102',
#               'd250'): [('pelvic and perineal pain',
#                'submucous leiomyoma of uterus')],
#              ('r142',
#               'y632'): [('eructation',
#                'overdose of radiation given during therapy')],
#              ('b86',
#               'p510'): [('scabies',
#                'massive umbilical hemorrhage of newborn')],
#              ('i249',
#               'r233'): [('acute ischemic heart disease, unspecified',
#                'spontaneous ecchymoses')],
#              ('p0739',
#               'r0782'): [('preterm newborn, gestational age 36 completed weeks',
#                'intercostal pain')],
#              ('m955',
#               'j60'): [('acquired deformity of pelvis',
#                "coalworker's pneumoconiosis")],
#              ('j311',
#               'q243'): [('chronic nasopharyngitis',
#                'pulmonary infundibular stenosis')],
#              ('m5114',
#               'g619'): [('intervertebral disc disorders with radiculopathy, thoracic region',
#                'inflammatory polyneuropathy, unspecified')],
#              ('l14',
#               'c100'): [('bullous disorders in diseases classified elsewhere',
#                'malignant neoplasm of vallecula')],
#              ('c511',
#               'c4000'): [('malignant neoplasm of labium minus',
#                'malignant neoplasm of scapula and long bones of unspecified upper limb')],
#              ('r062',
#               'g361'): [('wheezing',
#                'acute and subacute hemorrhagic leukoencephalitis [hurst]')],
#              ('p704',
#               'k225'): [('other neonatal hypoglycemia',
#                'diverticulum of esophagus, acquired')],
#              ('n843',
#               'k121'): [('polyp of vulva', 'other forms of stomatitis')],
#              ('q112',
#               'd101'): [('microphthalmos', 'benign neoplasm of tongue')],
#              ('q165',
#               'b159'): [('congenital malformation of inner ear',
#                'hepatitis a without hepatic coma')],
#              ('p155',
#               'd132'): [('birth injury to external genitalia',
#                'benign neoplasm of duodenum')],
#              ('m162',
#               'k250'): [('bilateral osteoarthritis resulting from hip dysplasia',
#                'acute gastric ulcer with hemorrhage')],
#              ('m159',
#               'k117'): [('polyosteoarthritis, unspecified',
#                'disturbances of salivary secretion')],
#              ('r209',
#               'a270'): [('unspecified disturbances of skin sensation',
#                'leptospirosis icterohemorrhagica')],
#              ('k610',
#               'f72'): [('anal abscess', 'severe intellectual disabilities')],
#              ('f422',
#               'r196'): [('mixed obsessional thoughts and acts', 'halitosis')],
#              ('k110', 'r294'): [('atrophy of salivary gland', 'clicking hip')],
#              ('c178',
#               'r94138'): [('malignant neoplasm of overlapping sites of small intestine',
#                'abnormal results of other function studies of peripheral nervous system')],
#              ('a054',
#               'd34'): [('foodborne bacillus cereus intoxication',
#                'benign neoplasm of thyroid gland')],
#              ('l210',
#               'e59'): [('seborrhea capitis', 'dietary selenium deficiency')],
#              ('d630',
#               'f314'): [('anemia in neoplastic disease',
#                'bipolar disorder, current episode depressed, severe, without psychotic features')],
#              ('g114',
#               'n926'): [('hereditary spastic paraplegia',
#                'irregular menstruation, unspecified')],
#              ('c467',
#               'p362'): [("kaposi's sarcoma of other sites",
#                'sepsis of newborn due to staphylococcus aureus')],
#              ('e163',
#               'o80'): [('increased secretion of glucagon',
#                'encounter for full-term uncomplicated delivery')],
#              ('p234',
#               'h2020'): [('congenital pneumonia due to escherichia coli',
#                'lens-induced iridocyclitis, unspecified eye')],
#              ('b5801',
#               'l130'): [('toxoplasma chorioretinitis',
#                'dermatitis herpetiformis')],
#              ('d119',
#               'c519'): [('benign neoplasm of major salivary gland, unspecified',
#                'malignant neoplasm of vulva, unspecified')],
#              ('l102',
#               'e270'): [('pemphigus foliaceous',
#                'other adrenocortical overactivity')],
#              ('f201',
#               'n1330'): [('disorganized schizophrenia',
#                'unspecified hydronephrosis')],
#              ('i745',
#               'r296'): [('embolism and thrombosis of iliac artery',
#                'repeated falls')],
#              ('r250',
#               'g250'): [('abnormal head movements', 'essential tremor')],
#              ('p0441',
#               'n650'): [('newborn affected by maternal use of cocaine',
#                'deformity of reconstructed breast')],
#              ('m059',
#               'f69'): [('rheumatoid arthritis with rheumatoid factor, unspecified',
#                'unspecified disorder of adult personality and behavior')],
#              ('a279',
#               'k142'): [('leptospirosis, unspecified',
#                'median rhomboid glossitis')],
#              ('r448',
#               'b20'): [('other symptoms and signs involving general sensations and perceptions',
#                'human immunodeficiency virus [hiv] disease')],
#              ('a222',
#               'c462'): [('gastrointestinal anthrax',
#                "kaposi's sarcoma of palate")],
#              ('f250',
#               'd150'): [('schizoaffective disorder, bipolar type',
#                'benign neoplasm of thymus')],
#              ('y69',
#               'm311'): [('unspecified misadventure during surgical and medical care',
#                'thrombotic microangiopathy')],
#              ('k37',
#               'k256'): [('unspecified appendicitis',
#                'chronic or unspecified gastric ulcer with both hemorrhage and perforation')],
#              ('j42',
#               'r404'): [('unspecified chronic bronchitis',
#                'transient alteration of awareness')],
#              ('b20',
#               'a281'): [('human immunodeficiency virus [hiv] disease',
#                'cat-scratch disease')],
#              ('k121',
#               'n843'): [('other forms of stomatitis', 'polyp of vulva')],
#              ('c318',
#               'r293'): [('malignant neoplasm of overlapping sites of accessory sinuses',
#                'abnormal posture')],
#              ('n926',
#               'g114'): [('irregular menstruation, unspecified',
#                'hereditary spastic paraplegia')],
#              ('r196',
#               'f422'): [('halitosis', 'mixed obsessional thoughts and acts')],
#              ('m910',
#               'd215'): [('juvenile osteochondrosis of pelvis',
#                'benign neoplasm of connective and other soft tissue of pelvis')],
#              ('f24',
#               'n879'): [('shared psychotic disorder',
#                'dysplasia of cervix uteri, unspecified')],
#              ('d282',
#               'r99'): [('benign neoplasm of uterine tubes and ligaments',
#                'ill-defined and unknown cause of mortality')],
#              ('f600',
#               'k582'): [('paranoid personality disorder',
#                'mixed irritable bowel syndrome')],
#              ('g110',
#               'g55'): [('congenital nonprogressive ataxia',
#                'nerve root and plexus compressions in diseases classified elsewhere')],
#              ('p510',
#               'p156'): [('massive umbilical hemorrhage of newborn',
#                'subcutaneous fat necrosis due to birth injury')],
#              ('m311',
#               'c101'): [('thrombotic microangiopathy',
#                'malignant neoplasm of anterior surface of epiglottis')],
#              ('d176',
#               'm152'): [('benign lipomatous neoplasm of spermatic cord',
#                "bouchard's nodes (with arthropathy)")],
#              ('a281',
#               'b20'): [('cat-scratch disease',
#                'human immunodeficiency virus [hiv] disease')],
#              ('m153',
#               'c154'): [('secondary multiple arthritis',
#                'malignant neoplasm of middle third of esophagus')],
#              ('r012',
#               'p234'): [('other cardiac sounds',
#                'congenital pneumonia due to escherichia coli')],
#              ('n492',
#               'f70'): [('inflammatory disorders of scrotum',
#                'mild intellectual disabilities')],
#              ('m162',
#               'm910'): [('bilateral osteoarthritis resulting from hip dysplasia',
#                'juvenile osteochondrosis of pelvis')],
#              ('a400',
#               'd220'): [('sepsis due to streptococcus, group a',
#                'melanocytic nevi of lip')],
#              ('e280',
#               'd015'): [('estrogen excess',
#                'carcinoma in situ of liver, gallbladder and bile ducts')],
#              ('d62',
#               'i213'): [('acute posthemorrhagic anemia',
#                'st elevation (stemi) myocardial infarction of unspecified site')],
#              ...})

# %%
with open('found_relations_glove_1000', 'w+') as output_file:  
    for keys, titles in results.items():
        output_file.write('{}:\n'.format(' '.join(keys)))
        for title in titles:
            output_file.write('    {}\n'.format(' || '.join(title)))

# %% [markdown]
# Create network for found relations

# %%
graph = nx.Graph()

# %%
graph.add_edges_from(results.keys())

# %%
nx.write_edgelist(graph, 'graph_glove_1000')

# %% [markdown]
# Load graph

# %%
graph = nx.read_edgelist('glove_analysis/graph_glove_1000')

# %% [markdown]
# Analysing found relations

# %%
icd10 = get_icd10_codes()

# %%
def retrieve_titles_for_subgraph(graph, icd10, min_nodes=2):
    subgraphs = list(nx.connected_component_subgraphs(graph))
    results = defaultdict(list)
    for subgraph in subgraphs:
        nodes = subgraph.nodes()
        if len(nodes) >= min_nodes:
            results[', '.join(nodes.keys())] = [icd10[node] for node in nodes]
    return results

# %%
results_titles = retrieve_titles_for_subgraph(graph, icd10)

# %%
with open('described_relations_glove_1000', 'w+') as output_file:  
    for keys, titles in results_titles.items():
        output_file.write('{}:\n'.format(keys))
        output_file.write('{}\n'.format('\n'.join(titles)))
        output_file.write('\n')
