# %%
from pprint import pprint
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
import numpy as np
import random
import smart_open
from collections import defaultdict
from tqdm import tqdm
from joblib import Parallel, delayed
import networkx as nx

# %% [markdown]
# Glove evaluation refactored

# %%
def generate_base(model_path, vocab_path):
    with open(vocab_path, 'r+') as f:
        words = [x.rstrip().split(' ')[0] for x in f.readlines()]
    with open(model_path, 'r') as f:
        vectors = {}
        for line in f:
            vals = line.rstrip().split(' ')
            vectors[vals[0]] = [float(x) for x in vals[1:]]

    vocab_size = len(words)
    vocab = {w: idx for idx, w in enumerate(words)}
    ivocab = {idx: w for idx, w in enumerate(words)}

    vector_dim = len(vectors[ivocab[0]])
    W = np.zeros((vocab_size, vector_dim))
    for word, v in vectors.items():
        if word == '<unk>':
            continue
        W[vocab[word], :] = v

    # normalize each word vector to unit variance
    W_norm = np.zeros(W.shape)
    d = (np.sum(W ** 2, 1) ** (0.5))
    W_norm = (W.T / d).T
    return (W_norm, vocab, ivocab)


def distance(base, input_term, topn):
    W, vocab, ivocab = base
    for idx, term in enumerate(input_term.split(' ')):
        if term in vocab:
            if idx == 0:
                vec_result = np.copy(W[vocab[term], :])
            else:
                vec_result += W[vocab[term], :]
        else:
            return # Word: Out of dictionary!

    vec_norm = np.zeros(vec_result.shape)
    d = (np.sum(vec_result ** 2,) ** (0.5))
    vec_norm = (vec_result.T / d).T

    dist = np.dot(W, vec_norm.T)

    for term in input_term.split(' '):
        index = vocab[term]
        dist[index] = -np.Inf

    a = np.argsort(-dist)[:topn]
    return [[ivocab[x], dist[x]] for x in a]

# %% [markdown]
# Get most similar words for code

# %%
def get_icd10_codes():
    icd10 = defaultdict()
    with open('../results/icd10cm_codes_2018.txt', 'r+') as f:
        for line in f.readlines():
            line = line.split()
            icd10[line[0].lower()] = ' '.join(line[1:]).lower()
        return icd10
    
    
def validate_relations(similarity_results, icd10):
    """Filter found words by cheking, whether they're valid icd10 codes."""
    found_relations = defaultdict(list)
    for reference, codes in tqdm(similarity_results.items()):
        for code, score in codes:
            if code.lower() in icd10.keys():
                found_relations[reference].append(code.lower())
    return found_relations


def describe_relations(found_relations, icd10):
    """Annotate every relation with titles of contained codes"""
    described_relations = defaultdict(list)
    for reference, relations in found_relations.items():
        for relation in relations:
            described_relations[(reference, relation)].append(
                (icd10[reference], icd10[relation]))
    return described_relations


def perform_analysis(model_path, vocab_path, topn=50):
    """Find relations between icd10 codes."""
    icd10 = get_icd10_codes()
    print('Loading vocabulary and vectors...')
    base = generate_base(model_path, vocab_path)
    print('Retrieving similar words...')
    similarity = Parallel(n_jobs=-1, backend='threading', verbose=10)(
        delayed(distance)(base, code, topn) for code in icd10.keys())
    similarity_results = defaultdict(list)
    for code, relations in zip(icd10.keys(), similarity):
        if relations:
            similarity_results[code] = relations
    print('Filtering similarities...')
    validated_relations = validate_relations(similarity_results, icd10=icd10)
    print('Describing relations...')
    return describe_relations(validated_relations, icd10=icd10)

# %%
results = perform_analysis('../results/glove_data/symmetric_vectors/glove_vectors50.txt', '../results/filtered_vocab_10.txt', topn=1000)
# Out:
# Loading vocabulary and vectors...
# Retrieving similar words...
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 917 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 1050 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 1097 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 1193 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 1293 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 1344 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 1397 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done 1505 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 1617 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 1674 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 1733 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 1853 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done 1914 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done 1977 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done 2040 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done 2105 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done 2170 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 2237 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done 2304 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done 2373 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=-1)]: Done 2513 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 2584 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 2657 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done 2730 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done 2805 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done 2880 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done 2957 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done 3034 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 3113 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 3273 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done 3354 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done 3437 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 3520 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 3605 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 3690 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 3777 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 3864 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done 3953 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 4133 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 4224 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 4317 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done 4410 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done 4505 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=-1)]: Done 4600 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done 4697 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done 4794 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 4893 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 4992 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 5093 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 5194 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 5297 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 5400 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done 5505 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done 5610 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=-1)]: Done 5717 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-1)]: Done 5824 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-1)]: Done 5933 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done 6042 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=-1)]: Done 6153 tasks      | elapsed:   17.7s
# [Parallel(n_jobs=-1)]: Done 6264 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-1)]: Done 6377 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done 6490 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-1)]: Done 6605 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-1)]: Done 6720 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=-1)]: Done 6837 tasks      | elapsed:   19.4s
# [Parallel(n_jobs=-1)]: Done 6954 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done 7073 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done 7192 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done 7313 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done 7434 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done 7557 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done 7680 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done 7805 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=-1)]: Done 7930 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=-1)]: Done 8057 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=-1)]: Done 8184 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=-1)]: Done 8313 tasks      | elapsed:   23.3s
# [Parallel(n_jobs=-1)]: Done 8442 tasks      | elapsed:   23.7s
# [Parallel(n_jobs=-1)]: Done 8573 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done 8704 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=-1)]: Done 8837 tasks      | elapsed:   25.1s
# [Parallel(n_jobs=-1)]: Done 8970 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=-1)]: Done 9105 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done 9240 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=-1)]: Done 9377 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=-1)]: Done 9514 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done 9653 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=-1)]: Done 9792 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=-1)]: Done 9933 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done 10074 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done 10217 tasks      | elapsed:   28.2s
# [Parallel(n_jobs=-1)]: Done 10360 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=-1)]: Done 10505 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=-1)]: Done 10650 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=-1)]: Done 10797 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=-1)]: Done 10944 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done 11093 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done 11242 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=-1)]: Done 11393 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 11544 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=-1)]: Done 11697 tasks      | elapsed:   32.8s
# [Parallel(n_jobs=-1)]: Done 11850 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=-1)]: Done 12005 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=-1)]: Done 12160 tasks      | elapsed:   34.1s
# [Parallel(n_jobs=-1)]: Done 12317 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done 12474 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done 12633 tasks      | elapsed:   35.3s
# [Parallel(n_jobs=-1)]: Done 12792 tasks      | elapsed:   36.1s
# [Parallel(n_jobs=-1)]: Done 12953 tasks      | elapsed:   36.2s
# [Parallel(n_jobs=-1)]: Done 13114 tasks      | elapsed:   36.5s
# [Parallel(n_jobs=-1)]: Done 13277 tasks      | elapsed:   37.4s
# [Parallel(n_jobs=-1)]: Done 13440 tasks      | elapsed:   37.5s
# [Parallel(n_jobs=-1)]: Done 13605 tasks      | elapsed:   38.3s
# [Parallel(n_jobs=-1)]: Done 13770 tasks      | elapsed:   38.8s
# [Parallel(n_jobs=-1)]: Done 13937 tasks      | elapsed:   39.2s
# [Parallel(n_jobs=-1)]: Done 14104 tasks      | elapsed:   39.9s
# [Parallel(n_jobs=-1)]: Done 14273 tasks      | elapsed:   40.5s
# [Parallel(n_jobs=-1)]: Done 14442 tasks      | elapsed:   41.2s
# [Parallel(n_jobs=-1)]: Done 14613 tasks      | elapsed:   41.7s
# [Parallel(n_jobs=-1)]: Done 14784 tasks      | elapsed:   42.2s
# [Parallel(n_jobs=-1)]: Done 14957 tasks      | elapsed:   42.3s
# [Parallel(n_jobs=-1)]: Done 15130 tasks      | elapsed:   43.4s
# [Parallel(n_jobs=-1)]: Done 15305 tasks      | elapsed:   44.0s
# [Parallel(n_jobs=-1)]: Done 15480 tasks      | elapsed:   44.6s
# [Parallel(n_jobs=-1)]: Done 15657 tasks      | elapsed:   45.1s
# [Parallel(n_jobs=-1)]: Done 15834 tasks      | elapsed:   45.8s
# [Parallel(n_jobs=-1)]: Done 16013 tasks      | elapsed:   46.3s
# [Parallel(n_jobs=-1)]: Done 16192 tasks      | elapsed:   46.8s
# [Parallel(n_jobs=-1)]: Done 16373 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=-1)]: Done 16554 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=-1)]: Done 16737 tasks      | elapsed:   48.4s
# [Parallel(n_jobs=-1)]: Done 16920 tasks      | elapsed:   49.1s
# [Parallel(n_jobs=-1)]: Done 17105 tasks      | elapsed:   49.7s
# [Parallel(n_jobs=-1)]: Done 17290 tasks      | elapsed:   50.3s
# [Parallel(n_jobs=-1)]: Done 17477 tasks      | elapsed:   50.9s
# [Parallel(n_jobs=-1)]: Done 17664 tasks      | elapsed:   52.1s
# [Parallel(n_jobs=-1)]: Done 17853 tasks      | elapsed:   53.0s
# [Parallel(n_jobs=-1)]: Done 18042 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=-1)]: Done 18233 tasks      | elapsed:   54.1s
# [Parallel(n_jobs=-1)]: Done 18424 tasks      | elapsed:   54.6s
# [Parallel(n_jobs=-1)]: Done 18617 tasks      | elapsed:   55.6s
# [Parallel(n_jobs=-1)]: Done 18810 tasks      | elapsed:   56.2s
# [Parallel(n_jobs=-1)]: Done 19005 tasks      | elapsed:   56.8s
# [Parallel(n_jobs=-1)]: Done 19200 tasks      | elapsed:   58.1s
# [Parallel(n_jobs=-1)]: Done 19397 tasks      | elapsed:   58.7s
# [Parallel(n_jobs=-1)]: Done 19594 tasks      | elapsed:   59.5s
# [Parallel(n_jobs=-1)]: Done 19793 tasks      | elapsed:   60.0s
# [Parallel(n_jobs=-1)]: Done 19992 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 20193 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 20394 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 20597 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 20800 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 21005 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 21210 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 21417 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 21624 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 21833 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 22042 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 22253 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 22464 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 22677 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 22890 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 23105 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 23320 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 23537 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 23754 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 23973 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 24192 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 24413 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 24634 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 24857 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 25080 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 25305 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 25530 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 25757 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 25984 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 26213 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 26442 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 26673 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 26904 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 27137 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 27370 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 27605 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 27840 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 28077 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 28314 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 28553 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 28792 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 29033 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 29274 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 29517 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 29760 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 30005 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 30250 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 30497 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 30744 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 30993 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 31242 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 31493 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 31744 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 31997 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 32250 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 32505 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 32760 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 33017 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 33274 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 33533 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 33792 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 34053 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 34314 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 34577 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 34840 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 35105 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 35370 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 35637 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 35904 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 36173 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 36442 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 36713 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 36984 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 37257 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 37530 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 37805 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 38080 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 38357 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 38634 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 38913 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 39192 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 39473 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 39754 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 40037 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 40320 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 40605 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 40890 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 41177 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 41464 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 41753 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 42042 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 42333 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 42624 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 42917 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 43210 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 43505 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 43800 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 44097 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 44394 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 44693 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 44992 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 45293 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 45594 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 45897 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 46200 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 46505 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 46810 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 47117 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 47424 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 47733 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 48042 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 48353 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 48664 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 48977 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 49290 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 49605 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 49920 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 50237 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 50554 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 50873 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 51192 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 51513 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 51834 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 52157 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 52480 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 52805 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 53130 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 53457 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 53784 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 54113 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 54442 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 54773 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 55104 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 55437 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 55770 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 56105 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 56440 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 56777 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 57114 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 57453 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 57792 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 58133 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 58474 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 58817 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 59160 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 59505 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 59850 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 60197 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 60544 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 60893 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 61242 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 61593 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 61944 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 62297 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 62650 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 63005 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 63360 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 63717 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 64074 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 64433 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 64792 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 65153 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 65514 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 65877 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 66240 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 66605 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 66970 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 67337 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 67704 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 68073 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 68442 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 68813 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 69184 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 69557 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 69930 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 70305 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 70680 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 71057 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 71434 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 71704 out of 71704 | elapsed:  3.5min finished
#  15%|█▌        | 272/1766 [00:00<00:01, 1363.02it/s]
# Filtering similarities...
# 100%|██████████| 1766/1766 [00:01<00:00, 1348.81it/s]
# Describing relations...

# %% [markdown]
# Saving relations

# %%
results
# Out:
# defaultdict(list,
#             {('p0081',
#               'n329'): [('newborn affected by periodontal disease in mother',
#                'bladder disorder, unspecified')],
#              ('n361',
#               'n151'): [('urethral diverticulum',
#                'renal and perinephric abscess')],
#              ('r52',
#               'd259'): [('pain, unspecified',
#                'leiomyoma of uterus, unspecified')],
#              ('k225',
#               'c002'): [('diverticulum of esophagus, acquired',
#                'malignant neoplasm of external lip, unspecified')],
#              ('q312',
#               'd210'): [('laryngeal hypoplasia',
#                'benign neoplasm of connective and other soft tissue of head, face and neck')],
#              ('n882',
#               'r0989'): [('stricture and stenosis of cervix uteri',
#                'other specified symptoms and signs involving the circulatory and respiratory systems')],
#              ('k599',
#               'o1205'): [('functional intestinal disorder, unspecified',
#                'gestational edema, complicating the puerperium')],
#              ('p7883',
#               'k011'): [('newborn esophageal reflux', 'impacted teeth')],
#              ('e163',
#               'e250'): [('increased secretion of glucagon',
#                'congenital adrenogenital disorders associated with enzyme deficiency')],
#              ('d77',
#               'm301'): [('other disorders of blood and blood-forming organs in diseases classified elsewhere',
#                'polyarteritis with lung involvement [churg-strauss]')],
#              ('h268',
#               'f79'): [('other specified cataract',
#                'unspecified intellectual disabilities')],
#              ('m151',
#               'k133'): [("heberden's nodes (with arthropathy)",
#                'hairy leukoplakia')],
#              ('q212',
#               'g132'): [('atrioventricular septal defect',
#                'systemic atrophy primarily affecting the central nervous system in myxedema')],
#              ('m182',
#               'd235'): [('bilateral post-traumatic osteoarthritis of first carpometacarpal joints',
#                'other benign neoplasm of skin of trunk')],
#              ('o210',
#               'e54'): [('mild hyperemesis gravidarum',
#                'ascorbic acid deficiency')],
#              ('n418',
#               'd126'): [('other inflammatory diseases of prostate',
#                'benign neoplasm of colon, unspecified')],
#              ('n926',
#               'l110'): [('irregular menstruation, unspecified',
#                'acquired keratosis follicularis')],
#              ('p358',
#               'd200'): [('other congenital viral diseases',
#                'benign neoplasm of soft tissue of retroperitoneum')],
#              ('r419',
#               'g894'): [('unspecified symptoms and signs involving cognitive functions and awareness',
#                'chronic pain syndrome')],
#              ('p0700',
#               'n913'): [('extremely low birth weight newborn, unspecified weight',
#                'primary oligomenorrhea')],
#              ('b389',
#               'd816'): [('coccidioidomycosis, unspecified',
#                'major histocompatibility complex class i deficiency')],
#              ('f429',
#               'n610'): [('obsessive-compulsive disorder, unspecified',
#                'mastitis without abscess')],
#              ('r330',
#               'd144'): [('drug induced retention of urine',
#                'benign neoplasm of respiratory system, unspecified')],
#              ('p191',
#               'n218'): [('metabolic acidemia in newborn first noted during labor',
#                'other lower urinary tract calculus')],
#              ('m318',
#               'k251'): [('other specified necrotizing vasculopathies',
#                'acute gastric ulcer with perforation')],
#              ('f320',
#               'r0782'): [('major depressive disorder, single episode, mild',
#                'intercostal pain')],
#              ('p525',
#               'p0500'): [('subarachnoid (nontraumatic) hemorrhage of newborn',
#                'newborn light for gestational age, unspecified weight')],
#              ('e321', 'r450'): [('abscess of thymus', 'nervousness')],
#              ('g311',
#               'p151'): [('senile degeneration of brain, not elsewhere classified',
#                'birth injury to spleen')],
#              ('q103',
#               'r0789'): [('other congenital malformations of eyelid',
#                'other chest pain')],
#              ('p024',
#               'n74'): [('newborn affected by prolapsed cord',
#                'female pelvic inflammatory disorders in diseases classified elsewhere')],
#              ('a835',
#               'c494'): [('california encephalitis',
#                'malignant neoplasm of connective and soft tissue of abdomen')],
#              ('a99',
#               'd170'): [('unspecified viral hemorrhagic fever',
#                'benign lipomatous neoplasm of skin and subcutaneous tissue of head, face and neck')],
#              ('r002',
#               'o169'): [('palpitations',
#                'unspecified maternal hypertension, unspecified trimester')],
#              ('k121',
#               'a199'): [('other forms of stomatitis',
#                'miliary tuberculosis, unspecified')],
#              ('b820',
#               'o159'): [('intestinal helminthiasis, unspecified',
#                'eclampsia, unspecified as to time period')],
#              ('c259',
#               'i675'): [('malignant neoplasm of pancreas, unspecified',
#                'moyamoya disease')],
#              ('o113',
#               'a260'): [('pre-existing hypertension with pre-eclampsia, third trimester',
#                'cutaneous erysipeloid')],
#              ('c55',
#               'p558'): [('malignant neoplasm of uterus, part unspecified',
#                'other hemolytic diseases of newborn')],
#              ('d290',
#               'a159'): [('benign neoplasm of penis',
#                'respiratory tuberculosis unspecified')],
#              ('p280',
#               'i120'): [('primary atelectasis of newborn',
#                'hypertensive chronic kidney disease with stage 5 chronic kidney disease or end stage renal disease')],
#              ('g309',
#               'f441'): [("alzheimer's disease, unspecified",
#                'dissociative fugue')],
#              ('a46', 'a150'): [('erysipelas', 'tuberculosis of lung')],
#              ('k274',
#               'd109'): [('chronic or unspecified peptic ulcer, site unspecified, with hemorrhage',
#                'benign neoplasm of pharynx, unspecified')],
#              ('a64',
#               'f410'): [('unspecified sexually transmitted disease',
#                'panic disorder [episodic paroxysmal anxiety]')],
#              ('l242',
#               'd630'): [('irritant contact dermatitis due to solvents',
#                'anemia in neoplastic disease')],
#              ('d144',
#               'g212'): [('benign neoplasm of respiratory system, unspecified',
#                'secondary parkinsonism due to other external agents')],
#              ('h209',
#               'r180'): [('unspecified iridocyclitis', 'malignant ascites')],
#              ('i745',
#               'j112'): [('embolism and thrombosis of iliac artery',
#                'influenza due to unidentified influenza virus with gastrointestinal manifestations')],
#              ('r34', 'a303'): [('anuria and oliguria', 'borderline leprosy')],
#              ('c439',
#               'p529'): [('malignant melanoma of skin, unspecified',
#                'intracranial (nontraumatic) hemorrhage of newborn, unspecified')],
#              ('k048',
#               'p138'): [('radicular cyst',
#                'birth injuries to other parts of skeleton')],
#              ('p122',
#               'd66'): [('epicranial subaponeurotic hemorrhage due to birth injury',
#                'hereditary factor viii deficiency')],
#              ('n470',
#               'f200'): [('adherent prepuce, newborn',
#                'paranoid schizophrenia')],
#              ('b54',
#               'c001'): [('unspecified malaria',
#                'malignant neoplasm of external lower lip')],
#              ('d385',
#               'k860'): [('neoplasm of uncertain behavior of other respiratory organs',
#                'alcohol-induced chronic pancreatitis')],
#              ('c721',
#               'e222'): [('malignant neoplasm of cauda equina',
#                'syndrome of inappropriate secretion of antidiuretic hormone')],
#              ('f451',
#               'k200'): [('undifferentiated somatoform disorder',
#                'eosinophilic esophagitis')],
#              ('e213',
#               'n900'): [('hyperparathyroidism, unspecified',
#                'mild vulvar dysplasia')],
#              ('o152',
#               'd520'): [('eclampsia complicating the puerperium',
#                'dietary folate deficiency anemia')],
#              ('c321',
#               'a09'): [('malignant neoplasm of supraglottis',
#                'infectious gastroenteritis and colitis, unspecified')],
#              ('q102',
#               'l111'): [('congenital entropion',
#                'transient acantholytic dermatosis [grover]')],
#              ('r130', 'p153'): [('aphagia', 'birth injury to eye')],
#              ('f310',
#               'b20'): [('bipolar disorder, current episode hypomanic',
#                'human immunodeficiency virus [hiv] disease')],
#              ('c240',
#               'o76'): [('malignant neoplasm of extrahepatic bile duct',
#                'abnormality in fetal heart rate and rhythm complicating labor and delivery')],
#              ('y700',
#               'c185'): [('diagnostic and monitoring anesthesiology devices associated with adverse incidents',
#                'malignant neoplasm of splenic flexure')],
#              ('g02',
#               'p704'): [('meningitis in other infectious and parasitic diseases classified elsewhere',
#                'other neonatal hypoglycemia')],
#              ('q141',
#               'y721'): [('congenital malformation of retina',
#                'therapeutic (nonsurgical) and rehabilitative otorhinolaryngological devices associated with adverse incidents')],
#              ('b356', 'a511'): [('tinea cruris', 'primary anal syphilis')],
#              ('c600',
#               'p150'): [('malignant neoplasm of prepuce',
#                'birth injury to liver')],
#              ('e54',
#               'o165'): [('ascorbic acid deficiency',
#                'unspecified maternal hypertension, complicating the puerperium')],
#              ('k433',
#               'r253'): [('parastomal hernia with obstruction, without gangrene',
#                'fasciculation')],
#              ('q209',
#               'd191'): [('congenital malformation of cardiac chambers and connections, unspecified',
#                'benign neoplasm of mesothelial tissue of peritoneum')],
#              ('q229',
#               'g729'): [('congenital malformation of tricuspid valve, unspecified',
#                'myopathy, unspecified')],
#              ('q263',
#               'g219'): [('partial anomalous pulmonary venous connection',
#                'secondary parkinsonism, unspecified')],
#              ('i130',
#               'd431'): [('hypertensive heart and chronic kidney disease with heart failure and stage 1 through stage 4 chronic kidney disease, or unspecified chronic kidney disease',
#                'neoplasm of uncertain behavior of brain, infratentorial')],
#              ('q311',
#               'r310'): [('congenital subglottic stenosis', 'gross hematuria')],
#              ('p014',
#               'r061'): [('newborn affected by ectopic pregnancy', 'stridor')],
#              ('r221',
#               'r51'): [('localized swelling, mass and lump, neck',
#                'headache')],
#              ('i161',
#               'b92'): [('hypertensive emergency', 'sequelae of leprosy')],
#              ('r52',
#               'h189'): [('pain, unspecified',
#                'unspecified disorder of cornea')],
#              ('b159',
#               'd492'): [('hepatitis a without hepatic coma',
#                'neoplasm of unspecified behavior of bone, soft tissue, and skin')],
#              ('a230',
#               'p261'): [('brucellosis due to brucella melitensis',
#                'massive pulmonary hemorrhage originating in the perinatal period')],
#              ('q253',
#               'c464'): [('supravalvular aortic stenosis',
#                "kaposi's sarcoma of gastrointestinal sites")],
#              ('n970',
#               'a430'): [('female infertility associated with anovulation',
#                'pulmonary nocardiosis')],
#              ('q221',
#               'a279'): [('congenital pulmonary valve stenosis',
#                'leptospirosis, unspecified')],
#              ('d612',
#               'm153'): [('aplastic anemia due to other external agents',
#                'secondary multiple arthritis')],
#              ('a305',
#               'z114'): [('lepromatous leprosy',
#                'encounter for screening for human immunodeficiency virus [hiv]')],
#              ('r231', 'q224'): [('pallor', 'congenital tricuspid stenosis')],
#              ('n931',
#               'c227'): [('pre-pubertal vaginal bleeding',
#                'other specified carcinomas of liver')],
#              ('p141',
#               'r180'): [("klumpke's paralysis due to birth injury",
#                'malignant ascites')],
#              ('k353',
#               'd191'): [('acute appendicitis with localized peritonitis',
#                'benign neoplasm of mesothelial tissue of peritoneum')],
#              ('p236',
#               'c311'): [('congenital pneumonia due to other bacterial agents',
#                'malignant neoplasm of ethmoidal sinus')],
#              ('c601',
#               'i32'): [('malignant neoplasm of glans penis',
#                'pericarditis in diseases classified elsewhere')],
#              ('q300',
#               'c461'): [('choanal atresia',
#                "kaposi's sarcoma of soft tissue")],
#              ('k560', 'p151'): [('paralytic ileus', 'birth injury to spleen')],
#              ('c55',
#               'k832'): [('malignant neoplasm of uterus, part unspecified',
#                'perforation of bile duct')],
#              ('g20',
#               'b581'): [("parkinson's disease", 'toxoplasma hepatitis')],
#              ('f340', 'r450'): [('cyclothymic disorder', 'nervousness')],
#              ('p290',
#               'a311'): [('neonatal cardiac failure',
#                'cutaneous mycobacterial infection')],
#              ('a302',
#               'y658'): [('borderline tuberculoid leprosy',
#                'other specified misadventures during surgical and medical care')],
#              ('d199',
#               'k033'): [('benign neoplasm of mesothelial tissue, unspecified',
#                'pathological resorption of teeth')],
#              ('n978',
#               'n879'): [('female infertility of other origin',
#                'dysplasia of cervix uteri, unspecified')],
#              ('c463',
#               'a311'): [("kaposi's sarcoma of lymph nodes",
#                'cutaneous mycobacterial infection')],
#              ('p53',
#               'a549'): [('hemorrhagic disease of newborn',
#                'gonococcal infection, unspecified')],
#              ('g118',
#               'n765'): [('other hereditary ataxias', 'ulceration of vagina')],
#              ('i675',
#               'k312'): [('moyamoya disease',
#                'hourglass stricture and stenosis of stomach')],
#              ('a054',
#               'e275'): [('foodborne bacillus cereus intoxication',
#                'adrenomedullary hyperfunction')],
#              ('y992',
#               'r448'): [('volunteer activity',
#                'other symptoms and signs involving general sensations and perceptions')],
#              ('r419',
#               'a870'): [('unspecified symptoms and signs involving cognitive functions and awareness',
#                'enteroviral meningitis')],
#              ('h268',
#               'i160'): [('other specified cataract', 'hypertensive urgency')],
#              ('e343',
#               'g110'): [('short stature due to endocrine disorder',
#                'congenital nonprogressive ataxia')],
#              ('k440',
#               'j17'): [('diaphragmatic hernia with obstruction, without gangrene',
#                'pneumonia in diseases classified elsewhere')],
#              ('n448',
#               'p153'): [('other noninflammatory disorders of the testis',
#                'birth injury to eye')],
#              ('j101',
#               'p570'): [('influenza due to other identified influenza virus with other respiratory manifestations',
#                'kernicterus due to isoimmunization')],
#              ('a90',
#               'n500'): [('dengue fever [classical dengue]',
#                'atrophy of testis')],
#              ('k254',
#               'm303'): [('chronic or unspecified gastric ulcer with hemorrhage',
#                'mucocutaneous lymph node syndrome [kawasaki]')],
#              ('i169',
#               'b380'): [('hypertensive crisis, unspecified',
#                'acute pulmonary coccidioidomycosis')],
#              ('b03', 'e321'): [('smallpox', 'abscess of thymus')],
#              ('i280',
#               'd117'): [('arteriovenous fistula of pulmonary vessels',
#                'benign neoplasm of other major salivary glands')],
#              ('p558',
#               'p742'): [('other hemolytic diseases of newborn',
#                'disturbances of sodium balance of newborn')],
#              ('f59',
#               'j101'): [('unspecified behavioral syndromes associated with physiological disturbances and physical factors',
#                'influenza due to other identified influenza virus with other respiratory manifestations')],
#              ('a159',
#               'k440'): [('respiratory tuberculosis unspecified',
#                'diaphragmatic hernia with obstruction, without gangrene')],
#              ('m270',
#               'k901'): [('developmental disorders of jaws', 'tropical sprue')],
#              ('n62',
#               'p011'): [('hypertrophy of breast',
#                'newborn affected by premature rupture of membranes')],
#              ('i129',
#               'n522'): [('hypertensive chronic kidney disease with stage 1 through stage 4 chronic kidney disease, or unspecified chronic kidney disease',
#                'drug-induced erectile dysfunction')],
#              ('q933',
#               'c261'): [('deletion of short arm of chromosome 4',
#                'malignant neoplasm of spleen')],
#              ('a430',
#               'm083'): [('pulmonary nocardiosis',
#                'juvenile rheumatoid polyarthritis (seronegative)')],
#              ('c240',
#               'a260'): [('malignant neoplasm of extrahepatic bile duct',
#                'cutaneous erysipeloid')],
#              ('e279',
#               'p746'): [('disorder of adrenal gland, unspecified',
#                'transitory hyperammonemia of newborn')],
#              ('k289',
#               'c720'): [('gastrojejunal ulcer, unspecified as acute or chronic, without hemorrhage or perforation',
#                'malignant neoplasm of spinal cord')],
#              ('i32',
#               'c601'): [('pericarditis in diseases classified elsewhere',
#                'malignant neoplasm of glans penis')],
#              ('q241',
#               'c714'): [('levocardia',
#                'malignant neoplasm of occipital lobe')],
#              ('r339',
#               'o164'): [('retention of urine, unspecified',
#                'unspecified maternal hypertension, complicating childbirth')],
#              ('c474',
#               'b889'): [('malignant neoplasm of peripheral nerves of abdomen',
#                'infestation, unspecified')],
#              ('b441',
#               'm14659'): [('other pulmonary aspergillosis',
#                "charcot's joint, unspecified hip")],
#              ('n900',
#               'n522'): [('mild vulvar dysplasia',
#                'drug-induced erectile dysfunction')],
#              ('n418',
#               'r201'): [('other inflammatory diseases of prostate',
#                'hypoesthesia of skin')],
#              ('p720',
#               'n311'): [('neonatal goiter, not elsewhere classified',
#                'reflex neuropathic bladder, not elsewhere classified')],
#              ('k37', 'r143'): [('unspecified appendicitis', 'flatulence')],
#              ('c148',
#               'e42'): [('malignant neoplasm of overlapping sites of lip, oral cavity and pharynx',
#                'marasmic kwashiorkor')],
#              ('r42',
#               'p139'): [('dizziness and giddiness',
#                'birth injury to skeleton, unspecified')],
#              ('a170',
#               'm184'): [('tuberculous meningitis',
#                'other bilateral secondary osteoarthritis of first carpometacarpal joints')],
#              ('f800',
#               'n477'): [('phonological disorder',
#                'other inflammatory diseases of prepuce')],
#              ('k219',
#               'n736'): [('gastro-esophageal reflux disease without esophagitis',
#                'female pelvic peritoneal adhesions (postinfective)')],
#              ('r94138',
#               'd224'): [('abnormal results of other function studies of peripheral nervous system',
#                'melanocytic nevi of scalp and neck')],
#              ('q105',
#               'e1100'): [('congenital stenosis and stricture of lacrimal duct',
#                'type 2 diabetes mellitus with hyperosmolarity without nonketotic hyperglycemic-hyperosmolar coma (nkhhc)')],
#              ('r071',
#               'p025'): [('chest pain on breathing',
#                'newborn affected by other compression of umbilical cord')],
#              ('g300',
#               'd166'): [("alzheimer's disease with early onset",
#                'benign neoplasm of vertebral column')],
#              ('p261',
#               'd201'): [('massive pulmonary hemorrhage originating in the perinatal period',
#                'benign neoplasm of soft tissue of peritoneum')],
#              ('c258',
#               'd242'): [('malignant neoplasm of overlapping sites of pancreas',
#                'benign neoplasm of left breast')],
#              ('k317',
#               'e243'): [('polyp of stomach and duodenum',
#                'ectopic acth syndrome')],
#              ('a362',
#               'y658'): [('laryngeal diphtheria',
#                'other specified misadventures during surgical and medical care')],
#              ('b559',
#               'b561'): [('leishmaniasis, unspecified',
#                'rhodesiense trypanosomiasis')],
#              ('o68',
#               'd251'): [('labor and delivery complicated by abnormality of fetal acid-base balance',
#                'intramural leiomyoma of uterus')],
#              ('a870',
#               'g894'): [('enteroviral meningitis', 'chronic pain syndrome')],
#              ('r21',
#               'r0603'): [('rash and other nonspecific skin eruption',
#                'acute respiratory distress')],
#              ('e163',
#               'a311'): [('increased secretion of glucagon',
#                'cutaneous mycobacterial infection')],
#              ('r180',
#               'h209'): [('malignant ascites', 'unspecified iridocyclitis')],
#              ('d109',
#               'k274'): [('benign neoplasm of pharynx, unspecified',
#                'chronic or unspecified peptic ulcer, site unspecified, with hemorrhage')],
#              ('k253',
#               'g114'): [('acute gastric ulcer without hemorrhage or perforation',
#                'hereditary spastic paraplegia')],
#              ('p520',
#               't310'): [('intraventricular (nontraumatic) hemorrhage, grade 1, of newborn',
#                'burns involving less than 10% of body surface')],
#              ('c4000',
#               'l120'): [('malignant neoplasm of scapula and long bones of unspecified upper limb',
#                'bullous pemphigoid')],
#              ('o80',
#               'e58'): [('encounter for full-term uncomplicated delivery',
#                'dietary calcium deficiency')],
#              ('d034',
#               'a57'): [('melanoma in situ of scalp and neck', 'chancroid')],
#              ('d65',
#               'l402'): [('disseminated intravascular coagulation [defibrination syndrome]',
#                'acrodermatitis continua')],
#              ('d171',
#               'r432'): [('benign lipomatous neoplasm of skin and subcutaneous tissue of trunk',
#                'parageusia')],
#              ('r295',
#               'd251'): [('transient paralysis',
#                'intramural leiomyoma of uterus')],
#              ('a227', 'r197'): [('anthrax sepsis', 'diarrhea, unspecified')],
#              ('z551',
#               'd197'): [('schooling unavailable and unattainable',
#                'benign neoplasm of mesothelial tissue of other sites')],
#              ('q143',
#               'b471'): [('congenital malformation of choroid',
#                'actinomycetoma')],
#              ('e109',
#               'b2701'): [('type 1 diabetes mellitus without complications',
#                'gammaherpesviral mononucleosis with polyneuropathy')],
#              ('r338',
#               'r150'): [('other retention of urine', 'incomplete defecation')],
#              ('c169',
#               'a054'): [('malignant neoplasm of stomach, unspecified',
#                'foodborne bacillus cereus intoxication')],
#              ('i259',
#               'a55'): [('chronic ischemic heart disease, unspecified',
#                'chlamydial lymphogranuloma (venereum)')],
#              ('r292', 'f22'): [('abnormal reflex', 'delusional disorders')],
#              ('n841',
#               'd144'): [('polyp of cervix uteri',
#                'benign neoplasm of respiratory system, unspecified')],
#              ('p102',
#               'e738'): [('intraventricular hemorrhage due to birth injury',
#                'other lactose intolerance')],
#              ('b334',
#               'b162'): [('hantavirus (cardio)-pulmonary syndrome [hps] [hcps]',
#                'acute hepatitis b without delta-agent with hepatic coma')],
#              ('q222',
#               'i249'): [('congenital pulmonary valve insufficiency',
#                'acute ischemic heart disease, unspecified')],
#              ('e54', 'r260'): [('ascorbic acid deficiency', 'ataxic gait')],
#              ('c601',
#               'l550'): [('malignant neoplasm of glans penis',
#                'sunburn of first degree')],
#              ('b5801',
#               'c162'): [('toxoplasma chorioretinitis',
#                'malignant neoplasm of body of stomach')],
#              ('l293',
#               'b2682'): [('anogenital pruritus, unspecified',
#                'mumps myocarditis')],
#              ('k271',
#               'q253'): [('acute peptic ulcer, site unspecified, with perforation',
#                'supravalvular aortic stenosis')],
#              ('k610', 'f21'): [('anal abscess', 'schizotypal disorder')],
#              ('d860',
#               'n454'): [('sarcoidosis of lung',
#                'abscess of epididymis or testis')],
#              ('a311',
#               'a440'): [('cutaneous mycobacterial infection',
#                'systemic bartonellosis')],
#              ('k117',
#               'l232'): [('disturbances of salivary secretion',
#                'allergic contact dermatitis due to cosmetics')],
#              ('p960',
#               'm2100'): [('congenital renal failure',
#                'valgus deformity, not elsewhere classified, unspecified site')],
#              ('k200',
#               'f451'): [('eosinophilic esophagitis',
#                'undifferentiated somatoform disorder')],
#              ('o68',
#               'r295'): [('labor and delivery complicated by abnormality of fetal acid-base balance',
#                'transient paralysis')],
#              ('r151',
#               'p138'): [('fecal smearing',
#                'birth injuries to other parts of skeleton')],
#              ('a985',
#               'b669'): [('hemorrhagic fever with renal syndrome',
#                'fluke infection, unspecified')],
#              ('o82',
#               'p501'): [('encounter for cesarean delivery without indication',
#                'newborn affected by intrauterine (fetal) blood loss from ruptured cord')],
#              ('r109',
#               'd282'): [('unspecified abdominal pain',
#                'benign neoplasm of uterine tubes and ligaments')],
#              ('k266',
#               'o169'): [('chronic or unspecified duodenal ulcer with both hemorrhage and perforation',
#                'unspecified maternal hypertension, unspecified trimester')],
#              ('n765',
#               'g118'): [('ulceration of vagina', 'other hereditary ataxias')],
#              ('d259',
#               'r52'): [('leiomyoma of uterus, unspecified',
#                'pain, unspecified')],
#              ('j101',
#               'f59'): [('influenza due to other identified influenza virus with other respiratory manifestations',
#                'unspecified behavioral syndromes associated with physiological disturbances and physical factors')],
#              ('t3262',
#               'p391'): [('corrosions involving 60-69% of body surface with 20-29% third degree corrosion',
#                'neonatal conjunctivitis and dacryocystitis')],
#              ('a260',
#               'c33'): [('cutaneous erysipeloid',
#                'malignant neoplasm of trachea')],
#              ('a55',
#               'd151'): [('chlamydial lymphogranuloma (venereum)',
#                'benign neoplasm of heart')],
#              ('n642',
#               'b002'): [('atrophy of breast',
#                'herpesviral gingivostomatitis and pharyngotonsillitis')],
#              ('p508',
#               'd392'): [('newborn affected by other intrauterine (fetal) blood loss',
#                'neoplasm of uncertain behavior of placenta')],
#              ('g119',
#               'd385'): [('hereditary ataxia, unspecified',
#                'neoplasm of uncertain behavior of other respiratory organs')],
#              ('a488',
#               'a752'): [('other specified bacterial diseases',
#                'typhus fever due to rickettsia typhi')],
#              ('d241',
#               'c37'): [('benign neoplasm of right breast',
#                'malignant neoplasm of thymus')],
#              ('n134',
#               'n159'): [('hydroureter',
#                'renal tubulo-interstitial disease, unspecified')],
#              ('i259',
#               'o630'): [('chronic ischemic heart disease, unspecified',
#                'prolonged first stage (of labor)')],
#              ('b04', 'p113'): [('monkeypox', 'birth injury to facial nerve')],
#              ('d609',
#               'c153'): [('acquired pure red cell aplasia, unspecified',
#                'malignant neoplasm of upper third of esophagus')],
#              ('d224',
#               'q171'): [('melanocytic nevi of scalp and neck', 'macrotia')],
#              ('d518',
#               'y904'): [('other vitamin b12 deficiency anemias',
#                'blood alcohol level of 80-99 mg/100 ml')],
#              ('f202',
#               'l242'): [('catatonic schizophrenia',
#                'irritant contact dermatitis due to solvents')],
#              ('l130',
#               'c110'): [('dermatitis herpetiformis',
#                'malignant neoplasm of superior wall of nasopharynx')],
#              ('d038',
#               'n393'): [('melanoma in situ of other sites',
#                'stress incontinence (female) (male)')],
#              ('f251',
#               'f70'): [('schizoaffective disorder, depressive type',
#                'mild intellectual disabilities')],
#              ('d107',
#               'g309'): [('benign neoplasm of hypopharynx',
#                "alzheimer's disease, unspecified")],
#              ('p261',
#               'a230'): [('massive pulmonary hemorrhage originating in the perinatal period',
#                'brucellosis due to brucella melitensis')],
#              ('e164',
#               'd259'): [('increased secretion of gastrin',
#                'leiomyoma of uterus, unspecified')],
#              ('a663',
#               'y632'): [('hyperkeratosis of yaws',
#                'overdose of radiation given during therapy')],
#              ('d241',
#               'b5801'): [('benign neoplasm of right breast',
#                'toxoplasma chorioretinitis')],
#              ('a94',
#               'o135'): [('unspecified arthropod-borne viral fever',
#                'gestational [pregnancy-induced] hypertension without significant proteinuria, complicating the puerperium')],
#              ('k832',
#               'p558'): [('perforation of bile duct',
#                'other hemolytic diseases of newborn')],
#              ('j121',
#               'a94'): [('respiratory syncytial virus pneumonia',
#                'unspecified arthropod-borne viral fever')],
#              ('p712',
#               'e42'): [('neonatal hypomagnesemia', 'marasmic kwashiorkor')],
#              ('c52',
#               'a201'): [('malignant neoplasm of vagina',
#                'cellulocutaneous plague')],
#              ('o901',
#               'a985'): [('disruption of perineal obstetric wound',
#                'hemorrhagic fever with renal syndrome')],
#              ('h28',
#               'k200'): [('cataract in diseases classified elsewhere',
#                'eosinophilic esophagitis')],
#              ('d191',
#               'f59'): [('benign neoplasm of mesothelial tissue of peritoneum',
#                'unspecified behavioral syndromes associated with physiological disturbances and physical factors')],
#              ('p911',
#               'd71'): [('acquired periventricular cysts of newborn',
#                'functional disorders of polymorphonuclear neutrophils')],
#              ('r202', 'r0601'): [('paresthesia of skin', 'orthopnea')],
#              ('r231', 'n641'): [('pallor', 'fat necrosis of breast')],
#              ('m1000',
#               'p711'): [('idiopathic gout, unspecified site',
#                'other neonatal hypocalcemia')],
#              ('e875', 'n766'): [('hyperkalemia', 'ulceration of vulva')],
#              ('e275',
#               'a054'): [('adrenomedullary hyperfunction',
#                'foodborne bacillus cereus intoxication')],
#              ('r94138',
#               'k901'): [('abnormal results of other function studies of peripheral nervous system',
#                'tropical sprue')],
#              ('z551',
#               'i280'): [('schooling unavailable and unattainable',
#                'arteriovenous fistula of pulmonary vessels')],
#              ('a380',
#               'd242'): [('scarlet fever with otitis media',
#                'benign neoplasm of left breast')],
#              ('a440',
#               'p290'): [('systemic bartonellosis',
#                'neonatal cardiac failure')],
#              ('r231',
#               'q230'): [('pallor', 'congenital stenosis of aortic valve')],
#              ('e41',
#               'p503'): [('nutritional marasmus',
#                'newborn affected by hemorrhage into co-twin')],
#              ('a33',
#               'l14'): [('tetanus neonatorum',
#                'bullous disorders in diseases classified elsewhere')],
#              ('d612',
#               'e1100'): [('aplastic anemia due to other external agents',
#                'type 2 diabetes mellitus with hyperosmolarity without nonketotic hyperglycemic-hyperosmolar coma (nkhhc)')],
#              ('d128',
#               'l109'): [('benign neoplasm of rectum',
#                'pemphigus, unspecified')],
#              ('f325',
#               'd201'): [('major depressive disorder, single episode, in full remission',
#                'benign neoplasm of soft tissue of peritoneum')],
#              ('b5801',
#               'c37'): [('toxoplasma chorioretinitis',
#                'malignant neoplasm of thymus')],
#              ('l122',
#               'd269'): [('chronic bullous disease of childhood',
#                'other benign neoplasm of uterus, unspecified')],
#              ('z550',
#               'c511'): [('illiteracy and low-level literacy',
#                'malignant neoplasm of labium minus')],
#              ('p003',
#               'p004'): [('newborn affected by other maternal circulatory and respiratory diseases',
#                'newborn affected by maternal nutritional disorders')],
#              ('f72',
#               'c159'): [('severe intellectual disabilities',
#                'malignant neoplasm of esophagus, unspecified')],
#              ('o68',
#               'k144'): [('labor and delivery complicated by abnormality of fetal acid-base balance',
#                'atrophy of tongue papillae')],
#              ('o210',
#               'r260'): [('mild hyperemesis gravidarum', 'ataxic gait')],
#              ('p0449',
#               'r310'): [('newborn affected by maternal use of other drugs of addiction',
#                'gross hematuria')],
#              ('n476',
#               'a213'): [('balanoposthitis', 'gastrointestinal tularemia')],
#              ('c189',
#               'c300'): [('malignant neoplasm of colon, unspecified',
#                'malignant neoplasm of nasal cavity')],
#              ('c499',
#               'a90'): [('malignant neoplasm of connective and soft tissue, unspecified',
#                'dengue fever [classical dengue]')],
#              ('y731',
#               'i150'): [('therapeutic (nonsurgical) and rehabilitative gastroenterology and urology devices associated with adverse incidents',
#                'renovascular hypertension')],
#              ('m166',
#               'n468'): [('other bilateral secondary osteoarthritis of hip',
#                'other male infertility')],
#              ('r52',
#               'y731'): [('pain, unspecified',
#                'therapeutic (nonsurgical) and rehabilitative gastroenterology and urology devices associated with adverse incidents')],
#              ('p232',
#               'f450'): [('congenital pneumonia due to staphylococcus',
#                'somatization disorder')],
#              ('c110',
#               'e169'): [('malignant neoplasm of superior wall of nasopharynx',
#                'disorder of pancreatic internal secretion, unspecified')],
#              ('a159',
#               'i38'): [('respiratory tuberculosis unspecified',
#                'endocarditis, valve unspecified')],
#              ('a752',
#               'p502'): [('typhus fever due to rickettsia typhi',
#                'newborn affected by intrauterine (fetal) blood loss from placenta')],
#              ('p150',
#               'c182'): [('birth injury to liver',
#                'malignant neoplasm of ascending colon')],
#              ('c254',
#               'r531'): [('malignant neoplasm of endocrine pancreas',
#                'weakness')],
#              ('p290',
#               'e163'): [('neonatal cardiac failure',
#                'increased secretion of glucagon')],
#              ('k219',
#               'k131'): [('gastro-esophageal reflux disease without esophagitis',
#                'cheek and lip biting')],
#              ('o169',
#               'k266'): [('unspecified maternal hypertension, unspecified trimester',
#                'chronic or unspecified duodenal ulcer with both hemorrhage and perforation')],
#              ('n501',
#               'd518'): [('vascular disorders of male genital organs',
#                'other vitamin b12 deficiency anemias')],
#              ('p159',
#               'e160'): [('birth injury, unspecified',
#                'drug-induced hypoglycemia without coma')],
#              ('n139',
#               'm158'): [('obstructive and reflux uropathy, unspecified',
#                'other polyosteoarthritis')],
#              ('a985',
#               'o901'): [('hemorrhagic fever with renal syndrome',
#                'disruption of perineal obstetric wound')],
#              ('f315',
#               'r252'): [('bipolar disorder, current episode depressed, severe, with psychotic features',
#                'cramp and spasm')],
#              ('r531',
#               'p114'): [('weakness', 'birth injury to other cranial nerves')],
#              ('m362',
#               'c714'): [('hemophilic arthropathy',
#                'malignant neoplasm of occipital lobe')],
#              ('k254',
#               'm720'): [('chronic or unspecified gastric ulcer with hemorrhage',
#                'palmar fascial fibromatosis [dupuytren]')],
#              ('r000',
#               't300'): [('tachycardia, unspecified',
#                'burn of unspecified body region, unspecified degree')],
#              ('g009',
#               'a212'): [('bacterial meningitis, unspecified',
#                'pulmonary tularemia')],
#              ('p0505',
#               'n492'): [('newborn light for gestational age, 1250-1499 grams',
#                'inflammatory disorders of scrotum')],
#              ('p391',
#               'c251'): [('neonatal conjunctivitis and dacryocystitis',
#                'malignant neoplasm of body of pancreas')],
#              ('d816',
#               'd267'): [('major histocompatibility complex class i deficiency',
#                'other benign neoplasm of other parts of uterus')],
#              ('g55',
#               'd210'): [('nerve root and plexus compressions in diseases classified elsewhere',
#                'benign neoplasm of connective and other soft tissue of head, face and neck')],
#              ('n920',
#               'k317'): [('excessive and frequent menstruation with regular cycle',
#                'polyp of stomach and duodenum')],
#              ('a400',
#               'd157'): [('sepsis due to streptococcus, group a',
#                'benign neoplasm of other specified intrathoracic organs')],
#              ('t310',
#               'p520'): [('burns involving less than 10% of body surface',
#                'intraventricular (nontraumatic) hemorrhage, grade 1, of newborn')],
#              ('l42',
#               'd250'): [('pityriasis rosea', 'submucous leiomyoma of uterus')],
#              ('g312',
#               'z9001'): [('degeneration of nervous system due to alcohol',
#                'acquired absence of eye')],
#              ('n888',
#               'n800'): [('other specified noninflammatory disorders of cervix uteri',
#                'endometriosis of uterus')],
#              ('i259',
#               'e71120'): [('chronic ischemic heart disease, unspecified',
#                'methylmalonic acidemia')],
#              ('e233',
#               'p121'): [('hypothalamic dysfunction, not elsewhere classified',
#                'chignon (from vacuum extraction) due to birth injury')],
#              ('g619',
#               'r481'): [('inflammatory polyneuropathy, unspecified',
#                'agnosia')],
#              ('i422',
#               'l243'): [('other hypertrophic cardiomyopathy',
#                'irritant contact dermatitis due to cosmetics')],
#              ('d66',
#               'a150'): [('hereditary factor viii deficiency',
#                'tuberculosis of lung')],
#              ('r0989',
#               'g94'): [('other specified symptoms and signs involving the circulatory and respiratory systems',
#                'other disorders of brain in diseases classified elsewhere')],
#              ('k560',
#               'c119'): [('paralytic ileus',
#                'malignant neoplasm of nasopharynx, unspecified')],
#              ('j112',
#               'n920'): [('influenza due to unidentified influenza virus with gastrointestinal manifestations',
#                'excessive and frequent menstruation with regular cycle')],
#              ('e280',
#               'p0739'): [('estrogen excess',
#                'preterm newborn, gestational age 36 completed weeks')],
#              ('m300',
#               'a86'): [('polyarteritis nodosa',
#                'unspecified viral encephalitis')],
#              ('e229',
#               'c720'): [('hyperfunction of pituitary gland, unspecified',
#                'malignant neoplasm of spinal cord')],
#              ('p191',
#               'd420'): [('metabolic acidemia in newborn first noted during labor',
#                'neoplasm of uncertain behavior of cerebral meninges')],
#              ('k080',
#               'd139'): [('exfoliation of teeth due to systemic causes',
#                'benign neoplasm of ill-defined sites within the digestive system')],
#              ('c461',
#               'q300'): [("kaposi's sarcoma of soft tissue",
#                'choanal atresia')],
#              ('b182',
#               'a233'): [('chronic viral hepatitis c',
#                'brucellosis due to brucella canis')],
#              ('c158',
#               'k353'): [('malignant neoplasm of overlapping sites of esophagus',
#                'acute appendicitis with localized peritonitis')],
#              ('g600',
#               'd067'): [('hereditary motor and sensory neuropathy',
#                'carcinoma in situ of other parts of cervix')],
#              ('f648',
#               'h119'): [('other gender identity disorders',
#                'unspecified disorder of conjunctiva')],
#              ('n472',
#               'n630'): [('paraphimosis',
#                'unspecified lump in unspecified breast')],
#              ('j17',
#               'a159'): [('pneumonia in diseases classified elsewhere',
#                'respiratory tuberculosis unspecified')],
#              ('q213',
#               'd65'): [('tetralogy of fallot',
#                'disseminated intravascular coagulation [defibrination syndrome]')],
#              ('k224',
#               'g59'): [('dyskinesia of esophagus',
#                'mononeuropathy in diseases classified elsewhere')],
#              ('e211',
#               'c112'): [('secondary hyperparathyroidism, not elsewhere classified',
#                'malignant neoplasm of lateral wall of nasopharynx')],
#              ('n413',
#               'd215'): [('prostatocystitis',
#                'benign neoplasm of connective and other soft tissue of pelvis')],
#              ('k269',
#               'q103'): [('duodenal ulcer, unspecified as acute or chronic, without hemorrhage or perforation',
#                'other congenital malformations of eyelid')],
#              ('i96',
#               'r0683'): [('gangrene, not elsewhere classified', 'snoring')],
#              ('q140',
#               'n132'): [('congenital malformation of vitreous humor',
#                'hydronephrosis with renal and ureteral calculous obstruction')],
#              ('e250',
#               'p290'): [('congenital adrenogenital disorders associated with enzyme deficiency',
#                'neonatal cardiac failure')],
#              ('b889',
#               'c474'): [('infestation, unspecified',
#                'malignant neoplasm of peripheral nerves of abdomen')],
#              ('h119',
#               'g544'): [('unspecified disorder of conjunctiva',
#                'lumbosacral root disorders, not elsewhere classified')],
#              ('b663',
#               'd039'): [('fascioliasis', 'melanoma in situ, unspecified')],
#              ('a240', 'e311'): [('glanders', 'polyglandular hyperfunction')],
#              ('d128',
#               'g02'): [('benign neoplasm of rectum',
#                'meningitis in other infectious and parasitic diseases classified elsewhere')],
#              ('i32',
#               'a190'): [('pericarditis in diseases classified elsewhere',
#                'acute miliary tuberculosis of a single specified site')],
#              ('n398',
#               'n420'): [('other specified disorders of urinary system',
#                'calculus of prostate')],
#              ('d375',
#               'n979'): [('neoplasm of uncertain behavior of rectum',
#                'female infertility, unspecified')],
#              ('r531',
#               'c254'): [('weakness',
#                'malignant neoplasm of endocrine pancreas')],
#              ('c750',
#               'o901'): [('malignant neoplasm of parathyroid gland',
#                'disruption of perineal obstetric wound')],
#              ('r066', 'n150'): [('hiccough', 'balkan nephropathy')],
#              ('g113',
#               'n403'): [('cerebellar ataxia with defective dna repair',
#                'nodular prostate with lower urinary tract symptoms')],
#              ('d229',
#               'i425'): [('melanocytic nevi, unspecified',
#                'other restrictive cardiomyopathy')],
#              ('a200', 'p151'): [('bubonic plague', 'birth injury to spleen')],
#              ('f70',
# ...
#              ('r062', 'r079'): [('wheezing', 'chest pain, unspecified')],
#              ('q261',
#               'g120'): [('persistent left superior vena cava',
#                'infantile spinal muscular atrophy, type i [werdnig-hoffman]')],
#              ('c211',
#               'c410'): [('malignant neoplasm of anal canal',
#                'malignant neoplasm of bones of skull and face')],
#              ('r230',
#               'e349'): [('cyanosis', 'endocrine disorder, unspecified')],
#              ('p159',
#               'n979'): [('birth injury, unspecified',
#                'female infertility, unspecified')],
#              ('m249',
#               'k582'): [('joint derangement, unspecified',
#                'mixed irritable bowel syndrome')],
#              ('c218',
#               'b471'): [('malignant neoplasm of overlapping sites of rectum, anus and anal canal',
#                'actinomycetoma')],
#              ('e139',
#               'p350'): [('other specified diabetes mellitus without complications',
#                'congenital rubella syndrome')],
#              ('e169',
#               't320'): [('disorder of pancreatic internal secretion, unspecified',
#                'corrosions involving less than 10% of body surface')],
#              ('a411',
#               'l240'): [('sepsis due to other specified staphylococcus',
#                'irritant contact dermatitis due to detergents')],
#              ('k832',
#               'p742'): [('perforation of bile duct',
#                'disturbances of sodium balance of newborn')],
#              ('r294',
#               'r58'): [('clicking hip',
#                'hemorrhage, not elsewhere classified')],
#              ('r330',
#               'g212'): [('drug induced retention of urine',
#                'secondary parkinsonism due to other external agents')],
#              ('b89',
#               'r339'): [('unspecified parasitic disease',
#                'retention of urine, unspecified')],
#              ('p910',
#               'l232'): [('neonatal cerebral ischemia',
#                'allergic contact dermatitis due to cosmetics')],
#              ('e02',
#               'm300'): [('subclinical iodine-deficiency hypothyroidism',
#                'polyarteritis nodosa')],
#              ('l130',
#               'e169'): [('dermatitis herpetiformis',
#                'disorder of pancreatic internal secretion, unspecified')],
#              ('o1205',
#               'k599'): [('gestational edema, complicating the puerperium',
#                'functional intestinal disorder, unspecified')],
#              ('e738',
#               'p108'): [('other lactose intolerance',
#                'other intracranial lacerations and hemorrhages due to birth injury')],
#              ('c227',
#               'r270'): [('other specified carcinomas of liver',
#                'ataxia, unspecified')],
#              ('t304',
#               'e1011'): [('corrosion of unspecified body region, unspecified degree',
#                'type 1 diabetes mellitus with ketoacidosis with coma')],
#              ('h109',
#               'a35'): [('unspecified conjunctivitis', 'other tetanus')],
#              ('q123',
#               'f82'): [('congenital aphakia',
#                'specific developmental disorder of motor function')],
#              ('m184',
#               'a170'): [('other bilateral secondary osteoarthritis of first carpometacarpal joints',
#                'tuberculous meningitis')],
#              ('p711',
#               'd019'): [('other neonatal hypocalcemia',
#                'carcinoma in situ of digestive organ, unspecified')],
#              ('r75',
#               'n920'): [('inconclusive laboratory evidence of human immunodeficiency virus [hiv]',
#                'excessive and frequent menstruation with regular cycle')],
#              ('p0511',
#               'f258'): [('newborn small for gestational age, less than 500 grams',
#                'other schizoaffective disorders')],
#              ('f79',
#               'c609'): [('unspecified intellectual disabilities',
#                'malignant neoplasm of penis, unspecified')],
#              ('d282',
#               'r109'): [('benign neoplasm of uterine tubes and ligaments',
#                'unspecified abdominal pain')],
#              ('c188',
#               'p615'): [('malignant neoplasm of overlapping sites of colon',
#                'transient neonatal neutropenia')],
#              ('e54',
#               'm179'): [('ascorbic acid deficiency',
#                'osteoarthritis of knee, unspecified')],
#              ('q219',
#               'l530'): [('congenital malformation of cardiac septum, unspecified',
#                'toxic erythema')],
#              ('r849',
#               'm179'): [('unspecified abnormal finding in specimens from respiratory organs and thorax',
#                'osteoarthritis of knee, unspecified')],
#              ('d200',
#               'q664'): [('benign neoplasm of soft tissue of retroperitoneum',
#                'congenital talipes calcaneovalgus')],
#              ('i120',
#               'z114'): [('hypertensive chronic kidney disease with stage 5 chronic kidney disease or end stage renal disease',
#                'encounter for screening for human immunodeficiency virus [hiv]')],
#              ('c301',
#               'd408'): [('malignant neoplasm of middle ear',
#                'neoplasm of uncertain behavior of other specified male genital organs')],
#              ('c720',
#               'e229'): [('malignant neoplasm of spinal cord',
#                'hyperfunction of pituitary gland, unspecified')],
#              ('p582',
#               'o151'): [('neonatal jaundice due to infection',
#                'eclampsia complicating labor')],
#              ('l550',
#               'p155'): [('sunburn of first degree',
#                'birth injury to external genitalia')],
#              ('l86',
#               'n322'): [('keratoderma in diseases classified elsewhere',
#                'vesical fistula, not elsewhere classified')],
#              ('y658',
#               'a302'): [('other specified misadventures during surgical and medical care',
#                'borderline tuberculoid leprosy')],
#              ('n500', 'n210'): [('atrophy of testis', 'calculus in bladder')],
#              ('m153',
#               'a182'): [('secondary multiple arthritis',
#                'tuberculous peripheral lymphadenopathy')],
#              ('b561',
#               'b559'): [('rhodesiense trypanosomiasis',
#                'leishmaniasis, unspecified')],
#              ('b0802',
#               'j14'): [('orf virus disease',
#                'pneumonia due to hemophilus influenzae')],
#              ('c229',
#               'f28'): [('malignant neoplasm of liver, not specified as primary or secondary',
#                'other psychotic disorder not due to a substance or known physiological condition')],
#              ('r330',
#               'n841'): [('drug induced retention of urine',
#                'polyp of cervix uteri')],
#              ('c210',
#               'f71'): [('malignant neoplasm of anus, unspecified',
#                'moderate intellectual disabilities')],
#              ('a390',
#               'k433'): [('meningococcal meningitis',
#                'parastomal hernia with obstruction, without gangrene')],
#              ('b661',
#               'r404'): [('clonorchiasis',
#                'transient alteration of awareness')],
#              ('q203',
#               'q221'): [('discordant ventriculoarterial connection',
#                'congenital pulmonary valve stenosis')],
#              ('r294',
#               'd485'): [('clicking hip',
#                'neoplasm of uncertain behavior of skin')],
#              ('b2682',
#               'd816'): [('mumps myocarditis',
#                'major histocompatibility complex class i deficiency')],
#              ('i32',
#               'p155'): [('pericarditis in diseases classified elsewhere',
#                'birth injury to external genitalia')],
#              ('n895',
#               'a523'): [('stricture and atresia of vagina',
#                'neurosyphilis, unspecified')],
#              ('o280',
#               'c178'): [('abnormal hematological finding on antenatal screening of mother',
#                'malignant neoplasm of overlapping sites of small intestine')],
#              ('m720',
#               'k254'): [('palmar fascial fibromatosis [dupuytren]',
#                'chronic or unspecified gastric ulcer with hemorrhage')],
#              ('e222',
#               'n201'): [('syndrome of inappropriate secretion of antidiuretic hormone',
#                'calculus of ureter')],
#              ('q209',
#               'f59'): [('congenital malformation of cardiac chambers and connections, unspecified',
#                'unspecified behavioral syndromes associated with physiological disturbances and physical factors')],
#              ('n840',
#               'l250'): [('polyp of corpus uteri',
#                'unspecified contact dermatitis due to cosmetics')],
#              ('b510',
#               'n410'): [('plasmodium vivax malaria with rupture of spleen',
#                'acute prostatitis')],
#              ('f258',
#               'p231'): [('other schizoaffective disorders',
#                'congenital pneumonia due to chlamydia')],
#              ('l209',
#               'o161'): [('atopic dermatitis, unspecified',
#                'unspecified maternal hypertension, first trimester')],
#              ('l209',
#               'k033'): [('atopic dermatitis, unspecified',
#                'pathological resorption of teeth')],
#              ('r34',
#               'e60'): [('anuria and oliguria', 'dietary zinc deficiency')],
#              ('e139',
#               'p154'): [('other specified diabetes mellitus without complications',
#                'birth injury to face')],
#              ('c227',
#               'n931'): [('other specified carcinomas of liver',
#                'pre-pubertal vaginal bleeding')],
#              ('d333',
#               'e242'): [('benign neoplasm of cranial nerves',
#                "drug-induced cushing's syndrome")],
#              ('d019',
#               'p711'): [('carcinoma in situ of digestive organ, unspecified',
#                'other neonatal hypocalcemia')],
#              ('m179',
#               'o165'): [('osteoarthritis of knee, unspecified',
#                'unspecified maternal hypertension, complicating the puerperium')],
#              ('m059',
#               'm342'): [('rheumatoid arthritis with rheumatoid factor, unspecified',
#                'systemic sclerosis induced by drug and chemical')],
#              ('k027',
#               'm720'): [('dental root caries',
#                'palmar fascial fibromatosis [dupuytren]')],
#              ('d269',
#               'p510'): [('other benign neoplasm of uterus, unspecified',
#                'massive umbilical hemorrhage of newborn')],
#              ('r450', 'f340'): [('nervousness', 'cyclothymic disorder')],
#              ('o135',
#               'a94'): [('gestational [pregnancy-induced] hypertension without significant proteinuria, complicating the puerperium',
#                'unspecified arthropod-borne viral fever')],
#              ('h7402',
#               'f1394'): [('tympanosclerosis, left ear',
#                'sedative, hypnotic or anxiolytic use, unspecified with sedative, hypnotic or anxiolytic-induced mood disorder')],
#              ('p113',
#               'p0081'): [('birth injury to facial nerve',
#                'newborn affected by periodontal disease in mother')],
#              ('p0502',
#               'd002'): [('newborn light for gestational age, 500-749 grams',
#                'carcinoma in situ of stomach')],
#              ('f71',
#               'q933'): [('moderate intellectual disabilities',
#                'deletion of short arm of chromosome 4')],
#              ('n410',
#               'd298'): [('acute prostatitis',
#                'benign neoplasm of other specified male genital organs')],
#              ('p558',
#               'c55'): [('other hemolytic diseases of newborn',
#                'malignant neoplasm of uterus, part unspecified')],
#              ('d351',
#               'a510'): [('benign neoplasm of parathyroid gland',
#                'primary genital syphilis')],
#              ('c700',
#               'n002'): [('malignant neoplasm of cerebral meninges',
#                'acute nephritic syndrome with diffuse membranous glomerulonephritis')],
#              ('n641', 'r231'): [('fat necrosis of breast', 'pallor')],
#              ('m109',
#               'r041'): [('gout, unspecified', 'hemorrhage from throat')],
#              ('k144',
#               'd251'): [('atrophy of tongue papillae',
#                'intramural leiomyoma of uterus')],
#              ('f324',
#               'k200'): [('major depressive disorder, single episode, in partial remission',
#                'eosinophilic esophagitis')],
#              ('r836',
#               'q175'): [('abnormal cytological findings in cerebrospinal fluid',
#                'prominent ear')],
#              ('b889',
#               'f28'): [('infestation, unspecified',
#                'other psychotic disorder not due to a substance or known physiological condition')],
#              ('l652', 'n413'): [('alopecia mucinosa', 'prostatocystitis')],
#              ('m151',
#               'r141'): [("heberden's nodes (with arthropathy)", 'gas pain')],
#              ('q211',
#               'q212'): [('atrial septal defect',
#                'atrioventricular septal defect')],
#              ('n931',
#               'e208'): [('pre-pubertal vaginal bleeding',
#                'other hypoparathyroidism')],
#              ('q132',
#               'd100'): [('other congenital malformations of iris',
#                'benign neoplasm of lip')],
#              ('b80',
#               'f71'): [('enterobiasis', 'moderate intellectual disabilities')],
#              ('k812',
#               'a288'): [('acute cholecystitis with chronic cholecystitis',
#                'other specified zoonotic bacterial diseases, not elsewhere classified')],
#              ('d141',
#               'm164'): [('benign neoplasm of larynx',
#                'bilateral post-traumatic osteoarthritis of hip')],
#              ('a250', 'b49'): [('spirillosis', 'unspecified mycosis')],
#              ('a288',
#               'i161'): [('other specified zoonotic bacterial diseases, not elsewhere classified',
#                'hypertensive emergency')],
#              ('l138',
#               'r42'): [('other specified bullous disorders',
#                'dizziness and giddiness')],
#              ('c720',
#               'k289'): [('malignant neoplasm of spinal cord',
#                'gastrojejunal ulcer, unspecified as acute or chronic, without hemorrhage or perforation')],
#              ('n738',
#               'p109'): [('other specified female pelvic inflammatory diseases',
#                'unspecified intracranial laceration and hemorrhage due to birth injury')],
#              ('r042',
#               'g361'): [('hemoptysis',
#                'acute and subacute hemorrhagic leukoencephalitis [hurst]')],
#              ('a310',
#               'd098'): [('pulmonary mycobacterial infection',
#                'carcinoma in situ of other specified sites')],
#              ('n08',
#               'g518'): [('glomerular disorders in diseases classified elsewhere',
#                'other disorders of facial nerve')],
#              ('l442',
#               'd282'): [('lichen striatus',
#                'benign neoplasm of uterine tubes and ligaments')],
#              ('n823',
#               'q180'): [('fistula of vagina to large intestine',
#                'sinus, fistula and cyst of branchial cleft')],
#              ('c108',
#               'b91'): [('malignant neoplasm of overlapping sites of oropharynx',
#                'sequelae of poliomyelitis')],
#              ('d179',
#               'r290'): [('benign lipomatous neoplasm, unspecified', 'tetany')],
#              ('r55',
#               'a400'): [('syncope and collapse',
#                'sepsis due to streptococcus, group a')],
#              ('b742',
#               'f632'): [('filariasis due to brugia timori', 'kleptomania')],
#              ...})

# %%
with open('glove_analysis/50/found_relations_glove50_1000', 'w+') as output_file:  
    for keys, titles in results.items():
        output_file.write('{}:\n'.format(' '.join(keys)))
        for title in titles:
            output_file.write('    {}\n'.format(' || '.join(title)))

# %% [markdown]
# Create network for found relations

# %%
graph = nx.Graph()

# %%
graph.add_edges_from(results.keys())

# %%
nx.write_edgelist(graph, 'glove_analysis/50/graph_glove50_1000')

# %% [markdown]
# Load graph

# %%
graph = nx.read_edgelist('glove_analysis/50/graph_glove50_1000')

# %% [markdown]
# Analysing found relations

# %%
icd10 = get_icd10_codes()

# %%
def retrieve_titles_for_subgraph(graph, icd10, min_nodes=2):
    subgraphs = list(nx.connected_component_subgraphs(graph))
    results = defaultdict(list)
    for subgraph in subgraphs:
        nodes = subgraph.nodes()
        if len(nodes) >= min_nodes:
            results[', '.join(nodes.keys())] = [icd10[node] for node in nodes]
    return results

# %%
results_titles = retrieve_titles_for_subgraph(graph, icd10)

# %%
with open('glove_analysis/50/described_relations_glove50_1000', 'w+') as output_file:  
    for keys, titles in results_titles.items():
        output_file.write('{}:\n'.format(keys))
        output_file.write('{}\n'.format('\n'.join(titles)))
        output_file.write('\n')
