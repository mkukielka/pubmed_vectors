# %%
from pprint import pprint
import numpy as np
import random
import smart_open
from collections import defaultdict
from tqdm import tqdm
from joblib import Parallel, delayed
import networkx as nx

# %% [markdown]
# Glove evaluation refactored

# %%
def generate_base(model_path, vocab_path):
    with open(vocab_path, 'r+') as f:
        words = [x.rstrip().split(' ')[0] for x in f.readlines()]
    with open(model_path, 'r') as f:
        vectors = {}
        for line in f:
            vals = line.rstrip().split(' ')
            vectors[vals[0]] = [float(x) for x in vals[1:]]

    vocab_size = len(words)
    vocab = {w: idx for idx, w in enumerate(words)}
    ivocab = {idx: w for idx, w in enumerate(words)}

    vector_dim = len(vectors[ivocab[0]])
    W = np.zeros((vocab_size, vector_dim))
    for word, v in vectors.items():
        if word == '<unk>':
            continue
        W[vocab[word], :] = v

    # normalize each word vector to unit variance
    W_norm = np.zeros(W.shape)
    d = (np.sum(W ** 2, 1) ** (0.5))
    W_norm = (W.T / d).T
    return (W_norm, vocab, ivocab)


def distance(base, input_term, topn):
    W, vocab, ivocab = base
    for idx, term in enumerate(input_term.split(' ')):
        if term in vocab:
            if idx == 0:
                vec_result = np.copy(W[vocab[term], :])
            else:
                vec_result += W[vocab[term], :]
        else:
            return # Word: Out of dictionary!

    vec_norm = np.zeros(vec_result.shape)
    d = (np.sum(vec_result ** 2,) ** (0.5))
    vec_norm = (vec_result.T / d).T

    dist = np.dot(W, vec_norm.T)

    for term in input_term.split(' '):
        index = vocab[term]
        dist[index] = -np.Inf

    a = np.argsort(-dist)[:topn]
    return [[ivocab[x], dist[x]] for x in a]

# %% [markdown]
# Get most similar words for code

# %%
def get_icd10_codes():
    icd10 = defaultdict()
    with open('../results/icd10cm_codes_2018.txt', 'r+') as f:
        for line in f.readlines():
            line = line.split()
            icd10[line[0].lower()] = ' '.join(line[1:]).lower()
        return icd10
    
    
def validate_relations(similarity_results, icd10):
    """Filter found words by cheking, whether they're valid icd10 codes."""
    found_relations = defaultdict(list)
    for reference, codes in tqdm(similarity_results.items()):
        for code, score in codes:
            if code.lower() in icd10.keys():
                found_relations[reference].append(code.lower())
    return found_relations


def describe_relations(found_relations, icd10):
    """Annotate every relation with titles of contained codes"""
    described_relations = defaultdict(list)
    for reference, relations in found_relations.items():
        for relation in relations:
            described_relations[(reference, relation)].append(
                (icd10[reference], icd10[relation]))
    return described_relations


def perform_analysis(model_path, vocab_path, topn=50):
    """Find relations between icd10 codes."""
    icd10 = get_icd10_codes()
    print('Loading vocabulary and vectors...')
    base = generate_base(model_path, vocab_path)
    print('Retrieving similar words...')
    similarity = Parallel(n_jobs=-1, backend='threading', verbose=10)(
        delayed(distance)(base, code, topn) for code in icd10.keys())
    similarity_results = defaultdict(list)
    for code, relations in zip(icd10.keys(), similarity):
        if relations:
            similarity_results[code] = relations
    print('Filtering similarities...')
    validated_relations = validate_relations(similarity_results, icd10=icd10)
    print('Describing relations...')
    return describe_relations(validated_relations, icd10=icd10)

# %%
results = perform_analysis('../results/glove_data/symmetric_vectors/glove_vectors150.txt', '../results/filtered_vocab_10.txt', topn=200)
# Out:
# Loading vocabulary and vectors...
# Retrieving similar words...
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done
# [Parallel(n_jobs=-1)]: Done 16013 tasks      | elapsed:   43.1s
# [Parallel(n_jobs=-1)]: Done 16192 tasks      | elapsed:   43.6s
# [Parallel(n_jobs=-1)]: Done 16373 tasks      | elapsed:   44.0s
# [Parallel(n_jobs=-1)]: Done 16554 tasks      | elapsed:   44.4s
# [Parallel(n_jobs=-1)]: Done 16737 tasks      | elapsed:   44.9s
# [Parallel(n_jobs=-1)]: Done 16920 tasks      | elapsed:   45.1s
# [Parallel(n_jobs=-1)]: Done 17105 tasks      | elapsed:   45.9s
# [Parallel(n_jobs=-1)]: Done 17290 tasks      | elapsed:   46.5s
# [Parallel(n_jobs=-1)]: Done 17477 tasks      | elapsed:   46.9s
# [Parallel(n_jobs=-1)]: Done 17664 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=-1)]: Done 17853 tasks      | elapsed:   48.9s
# [Parallel(n_jobs=-1)]: Done 18042 tasks      | elapsed:   49.0s
# [Parallel(n_jobs=-1)]: Done 18233 tasks      | elapsed:   49.6s
# [Parallel(n_jobs=-1)]: Done 18424 tasks      | elapsed:   49.8s
# [Parallel(n_jobs=-1)]: Done 18617 tasks      | elapsed:   50.0s
# [Parallel(n_jobs=-1)]: Done 18810 tasks      | elapsed:   50.4s
# [Parallel(n_jobs=-1)]: Done 19005 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=-1)]: Done 19200 tasks      | elapsed:   51.8s
# [Parallel(n_jobs=-1)]: Done 19397 tasks      | elapsed:   52.5s
# [Parallel(n_jobs=-1)]: Done 19594 tasks      | elapsed:   52.9s
# [Parallel(n_jobs=-1)]: Done 19793 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=-1)]: Done 19992 tasks      | elapsed:   53.8s
# [Parallel(n_jobs=-1)]: Done 20193 tasks      | elapsed:   54.5s
# [Parallel(n_jobs=-1)]: Done 20394 tasks      | elapsed:   55.2s
# [Parallel(n_jobs=-1)]: Done 20597 tasks      | elapsed:   55.9s
# [Parallel(n_jobs=-1)]: Done 20800 tasks      | elapsed:   56.9s
# [Parallel(n_jobs=-1)]: Done 21005 tasks      | elapsed:   57.4s
# [Parallel(n_jobs=-1)]: Done 21210 tasks      | elapsed:   57.8s
# [Parallel(n_jobs=-1)]: Done 21417 tasks      | elapsed:   57.9s
# [Parallel(n_jobs=-1)]: Done 21624 tasks      | elapsed:   58.3s
# [Parallel(n_jobs=-1)]: Done 21833 tasks      | elapsed:   59.1s
# [Parallel(n_jobs=-1)]: Done 22042 tasks      | elapsed:   59.1s
# [Parallel(n_jobs=-1)]: Done 22253 tasks      | elapsed:   59.8s
# [Parallel(n_jobs=-1)]: Done 22464 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 22677 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 22890 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 23105 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 23320 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 23537 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 23754 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 23973 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 24192 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 24413 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 24634 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 24857 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 25080 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 25305 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 25530 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 25757 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 25984 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 26213 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 26442 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 26673 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 26904 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 27137 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 27370 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 27605 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 27840 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 28077 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 28314 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 28553 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 28792 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 29033 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 29274 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 29517 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 29760 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 30005 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 30250 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 30497 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 30744 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 30993 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 31242 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 31493 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 31744 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 31997 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 32250 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 32505 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 32760 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 33017 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 33274 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 33533 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 33792 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 34053 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 34314 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 34577 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 34840 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 35105 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 35370 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 35637 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 35904 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 36173 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 36442 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 36713 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 36984 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 37257 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 37530 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 37805 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 38080 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 38357 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 38634 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 38913 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 39192 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 39473 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 39754 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 40037 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 40320 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 40605 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 40890 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 41177 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 41464 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 41753 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 42042 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 42333 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 42624 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 42917 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 43210 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 43505 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 43800 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 44097 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 44394 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 44693 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 44992 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 45293 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 45594 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 45897 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 46200 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 46505 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 46810 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 47117 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 47424 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 47733 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 48042 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 48353 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 48664 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 48977 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 49290 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 49605 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 49920 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 50237 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 50554 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 50873 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 51192 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 51513 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 51834 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 52157 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 52480 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 52805 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 53130 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 53457 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 53784 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 54113 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 54442 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 54773 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 55104 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 55437 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 55770 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 56105 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 56440 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 56777 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 57114 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 57453 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 57792 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 58133 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 58474 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 58817 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 59160 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 59505 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 59850 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 60197 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 60544 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 60893 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 61242 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 61593 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 61944 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 62297 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 62650 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 63005 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 63360 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 63717 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 64074 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 64433 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 64792 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 65153 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 65514 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 65877 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 66240 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 66605 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 66970 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 67337 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 67704 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 68073 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 68442 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 68813 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 69184 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 69557 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 69930 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 70305 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 70680 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 71057 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 71434 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 71704 out of 71704 | elapsed:  3.3min finished
#  73%|███████▎  | 1298/1766 [00:00<00:00, 6416.77it/s]
# Filtering similarities...
# 100%|██████████| 1766/1766 [00:00<00:00, 6464.84it/s]
# Describing relations...

# %% [markdown]
# Saving relations

# %%
len(results)
# Out:
# 663

# %%
with open('glove_analysis/150/found_relations_glove_200', 'w+') as output_file:  
    for keys, titles in results.items():
        output_file.write('{}:\n'.format(' '.join(keys)))
        for title in titles:
            output_file.write('    {}\n'.format(' || '.join(title)))

# %% [markdown]
# Create network for found relations

# %%
graph = nx.Graph()

# %%
graph.add_edges_from(results.keys())

# %%
nx.write_edgelist(graph, 'glove_analysis/150/graph_glove_200')

# %% [markdown]
# Load graph

# %%
graph = nx.read_edgelist('glove_analysis/150/graph_glove_200')

# %% [markdown]
# Analysing found relations

# %%
icd10 = get_icd10_codes()

# %%
def retrieve_titles_for_subgraph(graph, icd10, min_nodes=2):
    subgraphs = list(nx.connected_component_subgraphs(graph))
    results = defaultdict(list)
    for subgraph in subgraphs:
        nodes = subgraph.nodes()
        if len(nodes) >= min_nodes:
            results[', '.join(nodes.keys())] = [icd10[node] for node in nodes]
    return results

# %%
results_titles = retrieve_titles_for_subgraph(graph, icd10)

# %%
with open('glove_analysis/150/described_relations_glove_200', 'w+') as output_file:  
    for keys, titles in results_titles.items():
        output_file.write('{}:\n'.format(keys))
        output_file.write('{}\n'.format('\n'.join(titles)))
        output_file.write('\n')
